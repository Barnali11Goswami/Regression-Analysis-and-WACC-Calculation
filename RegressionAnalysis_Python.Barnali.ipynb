# %% [markdown]
# **GROUP NUMBER 13**
#
# Members:-
#
#
# 1) BARNALI GOSWAMI - 2022A2PS1859H
#
# 2) RAJAT SAMBARE - 2022A2PS1727H
#
# 3) MIHIR RAMAN - 2022A4PS1300H
#
# 4) U V YASHOVARDHAN REDDY- 2022A3PS0721H
#
# 5)
#
# 6)

# %%
#Install required libraries
# !pip install yfinance
import matplotlib.pyplot as plt
import statsmodels.api as sm
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.48)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
#Download stock prices for the security monthly data last 5 years
Cipla_df = yf.download('CIPLA.NS',
                      start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo'
)
Cipla_df.head()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                       CIPLA.NS    CIPLA.NS    CIPLA.NS    CIPLA.NS
# Date
# 2020-11-01 00:00:00+00:00  719.876831  745.599976  804.000000  706.500000
# 2020-12-01 00:00:00+00:00  791.661804  819.950012  839.000000  746.150024
# 2021-01-01 00:00:00+00:00  797.406555  825.900024  864.599976  796.200012
# 2021-02-01 00:00:00+00:00  759.896790  787.049988  878.900024  776.250000
# 2021-03-01 00:00:00+00:00  786.979126  815.099976  823.950012  738.099976
#
# Price                            Open     Volume
# Ticker                       CIPLA.NS   CIPLA.NS
# Date
# 2020-11-01 00:00:00+00:00  757.500000  177545799
# 2020-12-01 00:00:00+00:00  753.000000  135687822
# 2021-01-01 00:00:00+00:00  822.799988   89440283
# 2021-02-01 00:00:00+00:00  815.000000  109767415
# 2021-03-01 00:00:00+00:00  795.000000   74123652

# %%
#Download Market index closing prices
nifty_df = yf.download('^BSESN',start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo',
)
nifty_df.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  44149.718750  44149.718750  44825.371094
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
#
# Price                               Low          Open  Volume
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  39334.921875  39880.378906  407000
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000

# %%
#Calculate Log returns
nifty_df['Return_NIFTY'] = np.log(nifty_df['Adj Close']/nifty_df['Adj Close'].shift(1))
print(nifty_df['Return_NIFTY'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# 2021-05-01 00:00:00+00:00    0.062671
# 2021-06-01 00:00:00+00:00    0.010444
# 2021-07-01 00:00:00+00:00    0.001982
# 2021-08-01 00:00:00+00:00    0.090230
# 2021-09-01 00:00:00+00:00    0.026981
# 2021-10-01 00:00:00+00:00    0.003049
# 2021-11-01 00:00:00+00:00   -0.038537
# 2021-12-01 00:00:00+00:00    0.020621
# 2022-01-01 00:00:00+00:00   -0.004122
# 2022-02-01 00:00:00+00:00   -0.030930
# 2022-03-01 00:00:00+00:00    0.040440
# 2022-04-01 00:00:00+00:00   -0.026079
# 2022-05-01 00:00:00+00:00   -0.026540
# 2022-06-01 00:00:00+00:00   -0.046930
# 2022-07-01 00:00:00+00:00    0.082357
# 2022-08-01 00:00:00+00:00    0.033593
# 2022-09-01 00:00:00+00:00   -0.036086
# 2022-10-01 00:00:00+00:00    0.056198
# 2022-11-01 00:00:00+00:00    0.038004
# 2022-12-01 00:00:00+00:00   -0.036456
# 2023-01-01 00:00:00+00:00   -0.021445
# 2023-02-01 00:00:00+00:00   -0.009919
# 2023-03-01 00:00:00+00:00    0.000498
# 2023-04-01 00:00:00+00:00    0.035322
# 2023-05-01 00:00:00+00:00    0.024405
# 2023-06-01 00:00:00+00:00    0.032928
# 2023-07-01 00:00:00+00:00    0.027570
# 2023-08-01 00:00:00+00:00   -0.025828
# 2023-09-01 00:00:00+00:00    0.015261
# 2023-10-01 00:00:00+00:00   -0.030125
# 2023-11-01 00:00:00+00:00    0.047593
# 2023-12-01 00:00:00+00:00    0.075477
# 2024-01-01 00:00:00+00:00   -0.006780
# 2024-02-01 00:00:00+00:00    0.010373
# 2024-03-01 00:00:00+00:00    0.015752
# 2024-04-01 00:00:00+00:00    0.011225
# 2024-05-01 00:00:00+00:00   -0.007026
# 2024-06-01 00:00:00+00:00    0.066320
# 2024-07-01 00:00:00+00:00    0.033698
# 2024-08-01 00:00:00+00:00    0.007610
# 2024-09-01 00:00:00+00:00    0.023209
# 2024-10-01 00:00:00+00:00   -0.060019
# Name: Return_NIFTY, dtype: float64

# %%
nifty_df['Return_NIFTY'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df1 = nifty_df.dropna(axis=0)
nifty_df1.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
# 2021-04-01 00:00:00+00:00  48782.359375  48782.359375  50375.769531
#
# Price                               Low          Open  Volume Return_NIFTY
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400     0.078420
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300    -0.031172
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900     0.059024
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000     0.008299
# 2021-04-01 00:00:00+00:00  47204.500000  49868.531250  249700    -0.014789

# %%
#Caclulate log returns
Cipla_df['Return_CIPLA'] = np.log(Cipla_df['Adj Close']/Cipla_df['Adj Close'].shift(1))
print(Cipla_df['Return_CIPLA'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.095054
# 2021-01-01 00:00:00+00:00    0.007230
# 2021-02-01 00:00:00+00:00   -0.048182
# 2021-03-01 00:00:00+00:00    0.035019
# 2021-04-01 00:00:00+00:00    0.110518
# 2021-05-01 00:00:00+00:00    0.041949
# 2021-06-01 00:00:00+00:00    0.023475
# 2021-07-01 00:00:00+00:00   -0.054825
# 2021-08-01 00:00:00+00:00    0.029715
# 2021-09-01 00:00:00+00:00    0.042527
# 2021-10-01 00:00:00+00:00   -0.083178
# 2021-11-01 00:00:00+00:00    0.070645
# 2021-12-01 00:00:00+00:00   -0.028403
# 2022-01-01 00:00:00+00:00    0.000953
# 2022-02-01 00:00:00+00:00   -0.021337
# 2022-03-01 00:00:00+00:00    0.095797
# 2022-04-01 00:00:00+00:00   -0.036868
# 2022-05-01 00:00:00+00:00    0.011904
# 2022-06-01 00:00:00+00:00   -0.079355
# 2022-07-01 00:00:00+00:00    0.063570
# 2022-08-01 00:00:00+00:00    0.060589
# 2022-09-01 00:00:00+00:00    0.075927
# 2022-10-01 00:00:00+00:00    0.045969
# 2022-11-01 00:00:00+00:00   -0.024058
# 2022-12-01 00:00:00+00:00   -0.057517
# 2023-01-01 00:00:00+00:00   -0.055413
# 2023-02-01 00:00:00+00:00   -0.116065
# 2023-03-01 00:00:00+00:00   -0.006531
# 2023-04-01 00:00:00+00:00    0.008349
# 2023-05-01 00:00:00+00:00    0.048368
# 2023-06-01 00:00:00+00:00    0.062927
# 2023-07-01 00:00:00+00:00    0.146429
# 2023-08-01 00:00:00+00:00    0.084255
# 2023-09-01 00:00:00+00:00   -0.058492
# 2023-10-01 00:00:00+00:00    0.011609
# 2023-11-01 00:00:00+00:00    0.010198
# 2023-12-01 00:00:00+00:00    0.027660
# 2024-01-01 00:00:00+00:00    0.080666
# 2024-02-01 00:00:00+00:00    0.091433
# 2024-03-01 00:00:00+00:00    0.011151
# 2024-04-01 00:00:00+00:00   -0.066957
# 2024-05-01 00:00:00+00:00    0.033158
# 2024-06-01 00:00:00+00:00    0.022952
# 2024-07-01 00:00:00+00:00    0.041988
# 2024-08-01 00:00:00+00:00    0.069170
# 2024-09-01 00:00:00+00:00    0.007960
# 2024-10-01 00:00:00+00:00   -0.063874
# Name: Return_CIPLA, dtype: float64

# %%
Cipla_df1 = Cipla_df.dropna(axis=0)
Cipla_df1.head()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                       CIPLA.NS    CIPLA.NS    CIPLA.NS    CIPLA.NS
# Date
# 2020-12-01 00:00:00+00:00  791.661804  819.950012  839.000000  746.150024
# 2021-01-01 00:00:00+00:00  797.406555  825.900024  864.599976  796.200012
# 2021-02-01 00:00:00+00:00  759.896790  787.049988  878.900024  776.250000
# 2021-03-01 00:00:00+00:00  786.979126  815.099976  823.950012  738.099976
# 2021-04-01 00:00:00+00:00  878.942932  910.349976  966.349976  806.099976
#
# Price                            Open     Volume Return_CIPLA
# Ticker                       CIPLA.NS   CIPLA.NS
# Date
# 2020-12-01 00:00:00+00:00  753.000000  135687822     0.095054
# 2021-01-01 00:00:00+00:00  822.799988   89440283     0.007230
# 2021-02-01 00:00:00+00:00  815.000000  109767415    -0.048182
# 2021-03-01 00:00:00+00:00  795.000000   74123652     0.035019
# 2021-04-01 00:00:00+00:00  819.500000  173322333     0.110518

# %%
Cipla_df['Return_CIPLA'].plot(figsize=(8,5))
plt.show()

# %%
Cipla_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
Cipla_df1_returns = Cipla_df1['Return_CIPLA']
Cipla_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.095054
# 2021-01-01 00:00:00+00:00    0.007230
# 2021-02-01 00:00:00+00:00   -0.048182
# 2021-03-01 00:00:00+00:00    0.035019
# 2021-04-01 00:00:00+00:00    0.110518
# Name: Return_CIPLA, dtype: float64

# %%
nifty_df1_returns = nifty_df1['Return_NIFTY']
nifty_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# Name: Return_NIFTY, dtype: float64

# %%
returns = pd.merge(nifty_df1_returns,Cipla_df1_returns,how='inner',on='Date')
returns.head()
returns.describe()
# Out:
#        Return_NIFTY  Return_CIPLA
# count     47.000000     47.000000
# mean       0.012485      0.016342
# std        0.037319      0.058541
# min       -0.060019     -0.116065
# 25%       -0.018117     -0.026231
# 50%        0.010444      0.022952
# 75%        0.034510      0.061758
# max        0.090230      0.146429

# %%
sns.pairplot(returns)
plt.show()

# %%
sns.heatmap(returns.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
x = returns['Return_NIFTY']
y = returns['Return_CIPLA']
x_sm = sm.add_constant(x)

# %% [markdown]
# #Assumptions of OLS regression
# ##A linear relationship between the dependent and independent variables - The linear regression model is linear in parameters
# ##The independent variables are not highly correlated with each other - no multicollinearity
# ##The variance of the residuals is constant - no heteroskedasticity
# ##Random sampling of observation and no autocorrelation
# ##Assumption of Normality of Errors

# %% [markdown]
# ##Ri = αi + βi(RM) + εi.........Market model
#
# • Ri = Return of security i
#
# • αi = The return from the asset that is not related to the market’s return. This is “alpha” return from the security
#
# • βi = Beta or the return from the security explained by the market index’s return
#
# • RM = The market index’s return
#
# • εi = Error term for past returns not explained by the regression equation

# %%
#Regression - Market model
model = sm.OLS(y,x_sm)

# %% [markdown]
# #OLS estimation or Ordinary Least square Minimizes the sum of squared errors

# %%
results = model.fit()

# %%
#Regression result
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Return_CIPLA   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.068
# Method:                 Least Squares   F-statistic:                     4.348
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):             0.0427
# Time:                        07:32:11   Log-Likelihood:                 69.371
# No. Observations:                  47   AIC:                            -134.7
# Df Residuals:                      45   BIC:                            -131.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0105      0.009      1.210      0.233      -0.007       0.028
# Return_NIFTY     0.4656      0.223      2.085      0.043       0.016       0.915
# ==============================================================================
# Omnibus:                        0.284   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.868   Jarque-Bera (JB):                0.472
# Skew:                           0.078   Prob(JB):                        0.790
# Kurtosis:                       2.534   Cond. No.                         27.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #Beta for CIPLA stock = 0.46 and is  statistically significant as P value is less than 0.05 i.e. 0.028 (null hypothesis is rejected).

# %%
#Regression - Security Characteristic line
returns.info()
sns.regplot(x = 'Return_NIFTY', y = 'Return_CIPLA', data = returns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 47 entries, 2020-12-01 00:00:00+00:00 to 2024-10-01 00:00:00+00:00
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Return_NIFTY  47 non-null     float64
#  1   Return_CIPLA  47 non-null     float64
# dtypes: float64(2)
# memory usage: 1.1 KB
# <Axes: xlabel='Return_NIFTY', ylabel='Return_CIPLA'>

# %%
print('resid', results.resid)
# Out:
# resid Date
# 2020-12-01 00:00:00+00:00    0.048010
# 2021-01-01 00:00:00+00:00    0.011217
# 2021-02-01 00:00:00+00:00   -0.086195
# 2021-03-01 00:00:00+00:00    0.020627
# 2021-04-01 00:00:00+00:00    0.106876
# 2021-05-01 00:00:00+00:00    0.002238
# 2021-06-01 00:00:00+00:00    0.008084
# 2021-07-01 00:00:00+00:00   -0.066276
# 2021-08-01 00:00:00+00:00   -0.022828
# 2021-09-01 00:00:00+00:00    0.019435
# 2021-10-01 00:00:00+00:00   -0.095126
# 2021-11-01 00:00:00+00:00    0.078062
# 2021-12-01 00:00:00+00:00   -0.048534
# 2022-01-01 00:00:00+00:00   -0.007656
# 2022-02-01 00:00:00+00:00   -0.017463
# 2022-03-01 00:00:00+00:00    0.066438
# 2022-04-01 00:00:00+00:00   -0.035253
# 2022-05-01 00:00:00+00:00    0.013734
# 2022-06-01 00:00:00+00:00   -0.068030
# 2022-07-01 00:00:00+00:00    0.014693
# 2022-08-01 00:00:00+00:00    0.034418
# 2022-09-01 00:00:00+00:00    0.082202
# 2022-10-01 00:00:00+00:00    0.009273
# 2022-11-01 00:00:00+00:00   -0.052283
# 2022-12-01 00:00:00+00:00   -0.051070
# 2023-01-01 00:00:00+00:00   -0.055956
# 2023-02-01 00:00:00+00:00   -0.121975
# 2023-03-01 00:00:00+00:00   -0.017291
# 2023-04-01 00:00:00+00:00   -0.018626
# 2023-05-01 00:00:00+00:00    0.026476
# 2023-06-01 00:00:00+00:00    0.037066
# 2023-07-01 00:00:00+00:00    0.123063
# 2023-08-01 00:00:00+00:00    0.085753
# 2023-09-01 00:00:00+00:00   -0.076127
# 2023-10-01 00:00:00+00:00    0.015108
# 2023-11-01 00:00:00+00:00   -0.022492
# 2023-12-01 00:00:00+00:00   -0.018014
# 2024-01-01 00:00:00+00:00    0.073295
# 2024-02-01 00:00:00+00:00    0.076075
# 2024-03-01 00:00:00+00:00   -0.006712
# 2024-04-01 00:00:00+00:00   -0.082713
# 2024-05-01 00:00:00+00:00    0.025902
# 2024-06-01 00:00:00+00:00   -0.018458
# 2024-07-01 00:00:00+00:00    0.015769
# 2024-08-01 00:00:00+00:00    0.055098
# 2024-09-01 00:00:00+00:00   -0.013376
# 2024-10-01 00:00:00+00:00   -0.046455
# dtype: float64

# %%
#Histogram of residuals
sns.distplot(results.resid)
results.resid.describe()
# Out:
# <ipython-input-127-a89ebdceef41>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(results.resid)
# count    4.700000e+01
# mean    -4.429081e-19
# std      5.590189e-02
# min     -1.219747e-01
# 25%     -4.085372e-02
# 50%      2.237610e-03
# 75%      3.044666e-02
# max      1.230626e-01
# dtype: float64

# %%
#Checking for Homoskedasticity of errors (Assumption requirement of linear regression)
#perform White's test
from statsmodels.stats.diagnostic import het_white
white_test = het_white(results.resid,  results.model.exog)

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 3.2192472164624273, 'Test Statistic p-value': 0.19996286428865684, 'F-Statistic': 1.617684353495274, 'F-Test p-value': 0.20993172260046816}

# %% [markdown]
# #The errors are homoskedastic as per the White test

# %%
#Testing for Normality of errors (Assumption requirement of linear regression)
sm.qqplot(results.resid,line='45',fit=True,dist=stats.norm)

# %%
stats.normaltest(results.resid)
# Out:
# NormaltestResult(statistic=0.28361869524164474, pvalue=0.867786686311982)

# %% [markdown]
# We can see that since we are plotting the data with the theoretical quantiles of normal distribution, we are getting almost a straight line, though some points are exactly not on the line.
# The D'Agostino's K- squared test result suggests that the null hypothesis that the distribution is normal cannot be rejected at 1% significance level.

# %%
#Install required libraries
# !pip install yfinance
import matplotlib.pyplot as plt
import statsmodels.api as sm
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.48)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
#Download stock prices for the security monthly data last 5 years
sunpharma_df = yf.download('SUNPHARMA.NS',
                      start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo'
)
sunpharma_df.head()
# Out:
# Price                        Adj Close        Close         High          Low  \
# Ticker                    SUNPHARMA.NS SUNPHARMA.NS SUNPHARMA.NS SUNPHARMA.NS
# Date
# 2020-11-01 00:00:00+00:00   490.441895   511.649994   526.000000   459.049988
# 2020-12-01 00:00:00+00:00   567.796814   592.349976   599.450012   512.650024
# 2021-01-01 00:00:00+00:00   561.901794   586.200012   628.000000   550.400024
# 2021-02-01 00:00:00+00:00   569.953552   594.599976   654.400024   579.599976
# 2021-03-01 00:00:00+00:00   578.030273   597.799988   636.750000   562.099976
#
# Price                             Open       Volume
# Ticker                    SUNPHARMA.NS SUNPHARMA.NS
# Date
# 2020-11-01 00:00:00+00:00   467.899994    235023259
# 2020-12-01 00:00:00+00:00   518.000000    222828029
# 2021-01-01 00:00:00+00:00   592.500000    162671076
# 2021-02-01 00:00:00+00:00   596.000000    186129882
# 2021-03-01 00:00:00+00:00   600.000000    120684307

# %%
#Download Market index closing prices
nifty_df = yf.download('^BSESN',start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo',
)
nifty_df.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  44149.718750  44149.718750  44825.371094
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
#
# Price                               Low          Open  Volume
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  39334.921875  39880.378906  407000
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000

# %%
#Calculate Log returns
nifty_df['Return_NIFTY'] = np.log(nifty_df['Adj Close']/nifty_df['Adj Close'].shift(1))
print(nifty_df['Return_NIFTY'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# 2021-05-01 00:00:00+00:00    0.062671
# 2021-06-01 00:00:00+00:00    0.010444
# 2021-07-01 00:00:00+00:00    0.001982
# 2021-08-01 00:00:00+00:00    0.090230
# 2021-09-01 00:00:00+00:00    0.026981
# 2021-10-01 00:00:00+00:00    0.003049
# 2021-11-01 00:00:00+00:00   -0.038537
# 2021-12-01 00:00:00+00:00    0.020621
# 2022-01-01 00:00:00+00:00   -0.004122
# 2022-02-01 00:00:00+00:00   -0.030930
# 2022-03-01 00:00:00+00:00    0.040440
# 2022-04-01 00:00:00+00:00   -0.026079
# 2022-05-01 00:00:00+00:00   -0.026540
# 2022-06-01 00:00:00+00:00   -0.046930
# 2022-07-01 00:00:00+00:00    0.082357
# 2022-08-01 00:00:00+00:00    0.033593
# 2022-09-01 00:00:00+00:00   -0.036086
# 2022-10-01 00:00:00+00:00    0.056198
# 2022-11-01 00:00:00+00:00    0.038004
# 2022-12-01 00:00:00+00:00   -0.036456
# 2023-01-01 00:00:00+00:00   -0.021445
# 2023-02-01 00:00:00+00:00   -0.009919
# 2023-03-01 00:00:00+00:00    0.000498
# 2023-04-01 00:00:00+00:00    0.035322
# 2023-05-01 00:00:00+00:00    0.024405
# 2023-06-01 00:00:00+00:00    0.032928
# 2023-07-01 00:00:00+00:00    0.027570
# 2023-08-01 00:00:00+00:00   -0.025828
# 2023-09-01 00:00:00+00:00    0.015261
# 2023-10-01 00:00:00+00:00   -0.030125
# 2023-11-01 00:00:00+00:00    0.047593
# 2023-12-01 00:00:00+00:00    0.075477
# 2024-01-01 00:00:00+00:00   -0.006780
# 2024-02-01 00:00:00+00:00    0.010373
# 2024-03-01 00:00:00+00:00    0.015752
# 2024-04-01 00:00:00+00:00    0.011225
# 2024-05-01 00:00:00+00:00   -0.007026
# 2024-06-01 00:00:00+00:00    0.066320
# 2024-07-01 00:00:00+00:00    0.033698
# 2024-08-01 00:00:00+00:00    0.007610
# 2024-09-01 00:00:00+00:00    0.023209
# 2024-10-01 00:00:00+00:00   -0.060019
# Name: Return_NIFTY, dtype: float64

# %%
nifty_df['Return_NIFTY'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df1 = nifty_df.dropna(axis=0)
nifty_df1.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
# 2021-04-01 00:00:00+00:00  48782.359375  48782.359375  50375.769531
#
# Price                               Low          Open  Volume Return_NIFTY
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400     0.078420
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300    -0.031172
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900     0.059024
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000     0.008299
# 2021-04-01 00:00:00+00:00  47204.500000  49868.531250  249700    -0.014789

# %%
#Caclulate log returns
sunpharma_df['Return_SUNPHARMA'] = np.log(sunpharma_df['Adj Close']/sunpharma_df['Adj Close'].shift(1))
print(sunpharma_df['Return_SUNPHARMA'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.146457
# 2021-01-01 00:00:00+00:00   -0.010437
# 2021-02-01 00:00:00+00:00    0.014228
# 2021-03-01 00:00:00+00:00    0.014071
# 2021-04-01 00:00:00+00:00    0.090539
# 2021-05-01 00:00:00+00:00    0.020942
# 2021-06-01 00:00:00+00:00    0.010642
# 2021-07-01 00:00:00+00:00    0.136128
# 2021-08-01 00:00:00+00:00    0.025639
# 2021-09-01 00:00:00+00:00    0.032653
# 2021-10-01 00:00:00+00:00   -0.028826
# 2021-11-01 00:00:00+00:00   -0.053481
# 2021-12-01 00:00:00+00:00    0.115303
# 2022-01-01 00:00:00+00:00   -0.013332
# 2022-02-01 00:00:00+00:00    0.011201
# 2022-03-01 00:00:00+00:00    0.088477
# 2022-04-01 00:00:00+00:00    0.015081
# 2022-05-01 00:00:00+00:00   -0.076102
# 2022-06-01 00:00:00+00:00   -0.035482
# 2022-07-01 00:00:00+00:00    0.127130
# 2022-08-01 00:00:00+00:00   -0.054636
# 2022-09-01 00:00:00+00:00    0.063675
# 2022-10-01 00:00:00+00:00    0.069474
# 2022-11-01 00:00:00+00:00    0.028262
# 2022-12-01 00:00:00+00:00   -0.043622
# 2023-01-01 00:00:00+00:00    0.032519
# 2023-02-01 00:00:00+00:00   -0.078288
# 2023-03-01 00:00:00+00:00    0.034806
# 2023-04-01 00:00:00+00:00    0.004618
# 2023-05-01 00:00:00+00:00   -0.012532
# 2023-06-01 00:00:00+00:00    0.075272
# 2023-07-01 00:00:00+00:00    0.083694
# 2023-08-01 00:00:00+00:00   -0.024675
# 2023-09-01 00:00:00+00:00    0.041455
# 2023-10-01 00:00:00+00:00   -0.062363
# 2023-11-01 00:00:00+00:00    0.118742
# 2023-12-01 00:00:00+00:00    0.027041
# 2024-01-01 00:00:00+00:00    0.118890
# 2024-02-01 00:00:00+00:00    0.106562
# 2024-03-01 00:00:00+00:00    0.032323
# 2024-04-01 00:00:00+00:00   -0.075902
# 2024-05-01 00:00:00+00:00   -0.028565
# 2024-06-01 00:00:00+00:00    0.040970
# 2024-07-01 00:00:00+00:00    0.122677
# 2024-08-01 00:00:00+00:00    0.060962
# 2024-09-01 00:00:00+00:00    0.056066
# 2024-10-01 00:00:00+00:00   -0.041218
# Name: Return_SUNPHARMA, dtype: float64

# %%
sunpharma_df1 = sunpharma_df.dropna(axis=0)
sunpharma_df1.head()
# Out:
# Price                        Adj Close        Close         High          Low  \
# Ticker                    SUNPHARMA.NS SUNPHARMA.NS SUNPHARMA.NS SUNPHARMA.NS
# Date
# 2020-12-01 00:00:00+00:00   567.796814   592.349976   599.450012   512.650024
# 2021-01-01 00:00:00+00:00   561.901794   586.200012   628.000000   550.400024
# 2021-02-01 00:00:00+00:00   569.953552   594.599976   654.400024   579.599976
# 2021-03-01 00:00:00+00:00   578.030273   597.799988   636.750000   562.099976
# 2021-04-01 00:00:00+00:00   632.806824   654.450012   666.599976   592.750000
#
# Price                             Open       Volume Return_SUNPHARMA
# Ticker                    SUNPHARMA.NS SUNPHARMA.NS
# Date
# 2020-12-01 00:00:00+00:00        518.0    222828029         0.146457
# 2021-01-01 00:00:00+00:00        592.5    162671076        -0.010437
# 2021-02-01 00:00:00+00:00        596.0    186129882         0.014228
# 2021-03-01 00:00:00+00:00        600.0    120684307         0.014071
# 2021-04-01 00:00:00+00:00        600.0    162984571         0.090539

# %%
sunpharma_df['Return_SUNPHARMA'].plot(figsize=(8,5))
plt.show()

# %%
sunpharma_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
sunpharma_df1_returns = sunpharma_df1['Return_SUNPHARMA']
sunpharma_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.146457
# 2021-01-01 00:00:00+00:00   -0.010437
# 2021-02-01 00:00:00+00:00    0.014228
# 2021-03-01 00:00:00+00:00    0.014071
# 2021-04-01 00:00:00+00:00    0.090539
# Name: Return_SUNPHARMA, dtype: float64

# %%
nifty_df1_returns = nifty_df1['Return_NIFTY']
nifty_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# Name: Return_NIFTY, dtype: float64

# %%
returns = pd.merge(nifty_df1_returns,sunpharma_df1_returns,how='inner',on='Date')
returns.head()
returns.describe()
# Out:
#        Return_NIFTY  Return_SUNPHARMA
# count     47.000000         47.000000
# mean       0.012485          0.028235
# std        0.037319          0.062085
# min       -0.060019         -0.078288
# 25%       -0.018117         -0.019004
# 50%        0.010444          0.027041
# 75%        0.034510          0.072373
# max        0.090230          0.146457

# %%
sns.pairplot(returns)
plt.show()

# %%
sns.heatmap(returns.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
x = returns['Return_NIFTY']
y = returns['Return_SUNPHARMA']
x_sm = sm.add_constant(x)

# %% [markdown]
# #Assumptions of OLS regression
# ##A linear relationship between the dependent and independent variables - The linear regression model is linear in parameters
# ##The independent variables are not highly correlated with each other - no multicollinearity
# ##The variance of the residuals is constant - no heteroskedasticity
# ##Random sampling of observation and no autocorrelation
# ##Assumption of Normality of Errors

# %% [markdown]
# ##Ri = αi + βi(RM) + εi.........Market model
#
# • Ri = Return of security i
#
# • αi = The return from the asset that is not related to the market’s return. This is “alpha” return from the security
#
# • βi = Beta or the return from the security explained by the market index’s return
#
# • RM = The market index’s return
#
# • εi = Error term for past returns not explained by the regression equation

# %%
#Regression - Market model
model = sm.OLS(y,x_sm)

# %% [markdown]
# #OLS estimation or Ordinary Least square Minimizes the sum of squared errors

# %%
results = model.fit()

# %%
#Regression result
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Return_SUNPHARMA   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     12.97
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):           0.000787
# Time:                        07:16:08   Log-Likelihood:                 70.391
# No. Observations:                  47   AIC:                            -136.8
# Df Residuals:                      45   BIC:                            -133.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0184      0.009      2.162      0.036       0.001       0.036
# Return_NIFTY     0.7869      0.219      3.601      0.001       0.347       1.227
# ==============================================================================
# Omnibus:                        1.639   Durbin-Watson:                   2.393
# Prob(Omnibus):                  0.441   Jarque-Bera (JB):                1.307
# Skew:                           0.210   Prob(JB):                        0.520
# Kurtosis:                       2.300   Cond. No.                         27.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #Beta for SUN Pharmaceuticals stock = 0.78 and is statistically significant as P value is 0.036 and it's less than 5% (null hypothesis is rejected).

# %%
#Regression - Security Characteristic line
returns.info()
sns.regplot(x = 'Return_NIFTY', y = 'Return_SUNPHARMA', data = returns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 47 entries, 2020-12-01 00:00:00+00:00 to 2024-10-01 00:00:00+00:00
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Return_NIFTY      47 non-null     float64
#  1   Return_SUNPHARMA  47 non-null     float64
# dtypes: float64(2)
# memory usage: 1.1 KB
# <Axes: xlabel='Return_NIFTY', ylabel='Return_SUNPHARMA'>

# %%
print('resid', results.resid)
# Out:
# resid Date
# 2020-12-01 00:00:00+00:00    0.066338
# 2021-01-01 00:00:00+00:00   -0.004318
# 2021-02-01 00:00:00+00:00   -0.050629
# 2021-03-01 00:00:00+00:00   -0.010870
# 2021-04-01 00:00:00+00:00    0.083765
# 2021-05-01 00:00:00+00:00   -0.046784
# 2021-06-01 00:00:00+00:00   -0.015987
# 2021-07-01 00:00:00+00:00    0.116158
# 2021-08-01 00:00:00+00:00   -0.063773
# 2021-09-01 00:00:00+00:00   -0.006989
# 2021-10-01 00:00:00+00:00   -0.049636
# 2021-11-01 00:00:00+00:00   -0.041567
# 2021-12-01 00:00:00+00:00    0.080666
# 2022-01-01 00:00:00+00:00   -0.028499
# 2022-02-01 00:00:00+00:00    0.017129
# 2022-03-01 00:00:00+00:00    0.038244
# 2022-04-01 00:00:00+00:00    0.017191
# 2022-05-01 00:00:00+00:00   -0.073629
# 2022-06-01 00:00:00+00:00   -0.016964
# 2022-07-01 00:00:00+00:00    0.043913
# 2022-08-01 00:00:00+00:00   -0.099481
# 2022-09-01 00:00:00+00:00    0.073660
# 2022-10-01 00:00:00+00:00    0.006842
# 2022-11-01 00:00:00+00:00   -0.020054
# 2022-12-01 00:00:00+00:00   -0.033347
# 2023-01-01 00:00:00+00:00    0.030983
# 2023-02-01 00:00:00+00:00   -0.088893
# 2023-03-01 00:00:00+00:00    0.016003
# 2023-04-01 00:00:00+00:00   -0.041588
# 2023-05-01 00:00:00+00:00   -0.050147
# 2023-06-01 00:00:00+00:00    0.030950
# 2023-07-01 00:00:00+00:00    0.043588
# 2023-08-01 00:00:00+00:00   -0.022762
# 2023-09-01 00:00:00+00:00    0.011035
# 2023-10-01 00:00:00+00:00   -0.057069
# 2023-11-01 00:00:00+00:00    0.062881
# 2023-12-01 00:00:00+00:00   -0.050763
# 2024-01-01 00:00:00+00:00    0.105814
# 2024-02-01 00:00:00+00:00    0.079988
# 2024-03-01 00:00:00+00:00    0.001518
# 2024-04-01 00:00:00+00:00   -0.103146
# 2024-05-01 00:00:00+00:00   -0.041447
# 2024-06-01 00:00:00+00:00   -0.029628
# 2024-07-01 00:00:00+00:00    0.077749
# 2024-08-01 00:00:00+00:00    0.036563
# 2024-09-01 00:00:00+00:00    0.019392
# 2024-10-01 00:00:00+00:00   -0.012401
# dtype: float64

# %%
#Histogram of residuals
sns.distplot(results.resid)
results.resid.describe()
# Out:
# <ipython-input-45-a89ebdceef41>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(results.resid)
# count    4.700000e+01
# mean    -8.858162e-19
# std      5.470160e-02
# min     -1.031457e-01
# 25%     -4.157718e-02
# 50%     -6.989474e-03
# 75%      3.740380e-02
# max      1.161576e-01
# dtype: float64

# %%
#Checking for Homoskedasticity of errors (Assumption requirement of linear regression)
#perform White's test
from statsmodels.stats.diagnostic import het_white
white_test = het_white(results.resid,  results.model.exog)

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 1.4458200700919628, 'Test Statistic p-value': 0.4853378488217239, 'F-Statistic': 0.6982463868511012, 'F-Test p-value': 0.5028844976359652}

# %% [markdown]
# #The errors are homoskedastic as per the White test

# %%
#Testing for Normality of errors (Assumption requirement of linear regression)
sm.qqplot(results.resid,line='45',fit=True,dist=stats.norm)

# %%
stats.normaltest(results.resid)
# Out:
# NormaltestResult(statistic=1.6386248670692363, pvalue=0.44073458467230786)

# %% [markdown]
# We can see that since we are plotting the data with the theoretical quantiles of a normal distribution, we are getting almost a straight line, though some points are not exactly on the line.
# The D’Agostino’s K-squared test result suggests that the null hypothesis that the distribution is normal cannot be rejected at 1% significance level.

# %%
#Install required libraries
# !pip install yfinance
import matplotlib.pyplot as plt
import statsmodels.api as sm
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.48)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
#Download stock prices for the security monthly data last 5 years
drreddy_df = yf.download('DRREDDY.NS',
                      start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo'
)
drreddy_df.head()
# Out:
# Price                       Adj Close        Close         High         Low  \
# Ticker                     DRREDDY.NS   DRREDDY.NS   DRREDDY.NS  DRREDDY.NS
# Date
# 2020-11-01 00:00:00+00:00  890.768127   965.789978  1003.400024  931.260010
# 2020-12-01 00:00:00+00:00  960.154297  1041.020020  1054.839966  961.200012
# 2021-01-01 00:00:00+00:00  849.033142   920.539978  1088.699951  910.000000
# 2021-02-01 00:00:00+00:00  816.539734   885.309998   981.989990  875.400024
# 2021-03-01 00:00:00+00:00  833.040100   903.200012   916.669983  827.000000
#
# Price                             Open     Volume
# Ticker                      DRREDDY.NS DRREDDY.NS
# Date
# 2020-11-01 00:00:00+00:00   979.200012  152052745
# 2020-12-01 00:00:00+00:00   974.000000  137473980
# 2021-01-01 00:00:00+00:00  1043.449951   85885210
# 2021-02-01 00:00:00+00:00   912.010010  153630360
# 2021-03-01 00:00:00+00:00   889.000000   95846745

# %%
#Download Market index closing prices
nifty_df = yf.download('^BSESN',start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo',
)
nifty_df.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  44149.718750  44149.718750  44825.371094
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
#
# Price                               Low          Open  Volume
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  39334.921875  39880.378906  407000
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000

# %%
#Calculate Log returns
nifty_df['Return_NIFTY'] = np.log(nifty_df['Adj Close']/nifty_df['Adj Close'].shift(1))
print(nifty_df['Return_NIFTY'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# 2021-05-01 00:00:00+00:00    0.062671
# 2021-06-01 00:00:00+00:00    0.010444
# 2021-07-01 00:00:00+00:00    0.001982
# 2021-08-01 00:00:00+00:00    0.090230
# 2021-09-01 00:00:00+00:00    0.026981
# 2021-10-01 00:00:00+00:00    0.003049
# 2021-11-01 00:00:00+00:00   -0.038537
# 2021-12-01 00:00:00+00:00    0.020621
# 2022-01-01 00:00:00+00:00   -0.004122
# 2022-02-01 00:00:00+00:00   -0.030930
# 2022-03-01 00:00:00+00:00    0.040440
# 2022-04-01 00:00:00+00:00   -0.026079
# 2022-05-01 00:00:00+00:00   -0.026540
# 2022-06-01 00:00:00+00:00   -0.046930
# 2022-07-01 00:00:00+00:00    0.082357
# 2022-08-01 00:00:00+00:00    0.033593
# 2022-09-01 00:00:00+00:00   -0.036086
# 2022-10-01 00:00:00+00:00    0.056198
# 2022-11-01 00:00:00+00:00    0.038004
# 2022-12-01 00:00:00+00:00   -0.036456
# 2023-01-01 00:00:00+00:00   -0.021445
# 2023-02-01 00:00:00+00:00   -0.009919
# 2023-03-01 00:00:00+00:00    0.000498
# 2023-04-01 00:00:00+00:00    0.035322
# 2023-05-01 00:00:00+00:00    0.024405
# 2023-06-01 00:00:00+00:00    0.032928
# 2023-07-01 00:00:00+00:00    0.027570
# 2023-08-01 00:00:00+00:00   -0.025828
# 2023-09-01 00:00:00+00:00    0.015261
# 2023-10-01 00:00:00+00:00   -0.030125
# 2023-11-01 00:00:00+00:00    0.047593
# 2023-12-01 00:00:00+00:00    0.075477
# 2024-01-01 00:00:00+00:00   -0.006780
# 2024-02-01 00:00:00+00:00    0.010373
# 2024-03-01 00:00:00+00:00    0.015752
# 2024-04-01 00:00:00+00:00    0.011225
# 2024-05-01 00:00:00+00:00   -0.007026
# 2024-06-01 00:00:00+00:00    0.066320
# 2024-07-01 00:00:00+00:00    0.033698
# 2024-08-01 00:00:00+00:00    0.007610
# 2024-09-01 00:00:00+00:00    0.023209
# 2024-10-01 00:00:00+00:00   -0.060019
# Name: Return_NIFTY, dtype: float64

# %%
nifty_df['Return_NIFTY'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df1 = nifty_df.dropna(axis=0)
nifty_df1.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
# 2021-04-01 00:00:00+00:00  48782.359375  48782.359375  50375.769531
#
# Price                               Low          Open  Volume Return_NIFTY
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400     0.078420
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300    -0.031172
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900     0.059024
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000     0.008299
# 2021-04-01 00:00:00+00:00  47204.500000  49868.531250  249700    -0.014789

# %%
#Caclulate log returns
drreddy_df['Return_DRREDDY'] = np.log(drreddy_df['Adj Close']/drreddy_df['Adj Close'].shift(1))
print(drreddy_df['Return_DRREDDY'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.075010
# 2021-01-01 00:00:00+00:00   -0.122996
# 2021-02-01 00:00:00+00:00   -0.039023
# 2021-03-01 00:00:00+00:00    0.020006
# 2021-04-01 00:00:00+00:00    0.133911
# 2021-05-01 00:00:00+00:00    0.027895
# 2021-06-01 00:00:00+00:00    0.021227
# 2021-07-01 00:00:00+00:00   -0.140716
# 2021-08-01 00:00:00+00:00    0.003065
# 2021-09-01 00:00:00+00:00    0.036865
# 2021-10-01 00:00:00+00:00   -0.046445
# 2021-11-01 00:00:00+00:00    0.003567
# 2021-12-01 00:00:00+00:00    0.048252
# 2022-01-01 00:00:00+00:00   -0.131397
# 2022-02-01 00:00:00+00:00   -0.057246
# 2022-03-01 00:00:00+00:00    0.055536
# 2022-04-01 00:00:00+00:00   -0.038807
# 2022-05-01 00:00:00+00:00    0.055933
# 2022-06-01 00:00:00+00:00    0.005511
# 2022-07-01 00:00:00+00:00   -0.071564
# 2022-08-01 00:00:00+00:00    0.043955
# 2022-09-01 00:00:00+00:00    0.021130
# 2022-10-01 00:00:00+00:00    0.022351
# 2022-11-01 00:00:00+00:00    0.011983
# 2022-12-01 00:00:00+00:00   -0.057232
# 2023-01-01 00:00:00+00:00    0.020230
# 2023-02-01 00:00:00+00:00   -0.001748
# 2023-03-01 00:00:00+00:00    0.068522
# 2023-04-01 00:00:00+00:00    0.064319
# 2023-05-01 00:00:00+00:00   -0.090998
# 2023-06-01 00:00:00+00:00    0.136548
# 2023-07-01 00:00:00+00:00    0.089105
# 2023-08-01 00:00:00+00:00    0.033774
# 2023-09-01 00:00:00+00:00   -0.003725
# 2023-10-01 00:00:00+00:00   -0.040071
# 2023-11-01 00:00:00+00:00    0.075441
# 2023-12-01 00:00:00+00:00    0.001683
# 2024-01-01 00:00:00+00:00    0.054254
# 2024-02-01 00:00:00+00:00    0.048330
# 2024-03-01 00:00:00+00:00   -0.042344
# 2024-04-01 00:00:00+00:00    0.007507
# 2024-05-01 00:00:00+00:00   -0.068791
# 2024-06-01 00:00:00+00:00    0.100213
# 2024-07-01 00:00:00+00:00    0.052951
# 2024-08-01 00:00:00+00:00    0.070639
# 2024-09-01 00:00:00+00:00   -0.040599
# 2024-10-01 00:00:00+00:00   -0.058023
# Name: Return_DRREDDY, dtype: float64

# %%
drreddy_df1 = drreddy_df.dropna(axis=0)
drreddy_df1.head()
# Out:
# Price                       Adj Close        Close         High         Low  \
# Ticker                     DRREDDY.NS   DRREDDY.NS   DRREDDY.NS  DRREDDY.NS
# Date
# 2020-12-01 00:00:00+00:00  960.154297  1041.020020  1054.839966  961.200012
# 2021-01-01 00:00:00+00:00  849.033142   920.539978  1088.699951  910.000000
# 2021-02-01 00:00:00+00:00  816.539734   885.309998   981.989990  875.400024
# 2021-03-01 00:00:00+00:00  833.040100   903.200012   916.669983  827.000000
# 2021-04-01 00:00:00+00:00  952.406860  1032.619995  1058.000000  884.780029
#
# Price                             Open     Volume Return_DRREDDY
# Ticker                      DRREDDY.NS DRREDDY.NS
# Date
# 2020-12-01 00:00:00+00:00   974.000000  137473980       0.075010
# 2021-01-01 00:00:00+00:00  1043.449951   85885210      -0.122996
# 2021-02-01 00:00:00+00:00   912.010010  153630360      -0.039023
# 2021-03-01 00:00:00+00:00   889.000000   95846745       0.020006
# 2021-04-01 00:00:00+00:00   910.000000  152668490       0.133911

# %%
drreddy_df['Return_DRREDDY'].plot(figsize=(8,5))
plt.show()

# %%
drreddy_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
drreddy_df1_returns = drreddy_df1['Return_DRREDDY']
drreddy_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.075010
# 2021-01-01 00:00:00+00:00   -0.122996
# 2021-02-01 00:00:00+00:00   -0.039023
# 2021-03-01 00:00:00+00:00    0.020006
# 2021-04-01 00:00:00+00:00    0.133911
# Name: Return_DRREDDY, dtype: float64

# %%
nifty_df1_returns = nifty_df1['Return_NIFTY']
nifty_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# Name: Return_NIFTY, dtype: float64

# %%
returns = pd.merge(nifty_df1_returns,drreddy_df1_returns,how='inner',on='Date')
returns.head()
returns.describe()
# Out:
#        Return_NIFTY  Return_DRREDDY
# count     47.000000       47.000000
# mean       0.012485        0.007617
# std        0.037319        0.064566
# min       -0.060019       -0.140716
# 25%       -0.018117       -0.040335
# 50%        0.010444        0.020006
# 75%        0.034510        0.053603
# max        0.090230        0.136548

# %%
sns.pairplot(returns)
plt.show()

# %%
sns.heatmap(returns.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
x = returns['Return_NIFTY']
y = returns['Return_DRREDDY']
x_sm = sm.add_constant(x)

# %% [markdown]
# #Assumptions of OLS regression
# ##A linear relationship between the dependent and independent variables - The linear regression model is linear in parameters
# ##The independent variables are not highly correlated with each other - no multicollinearity
# ##The variance of the residuals is constant - no heteroskedasticity
# ##Random sampling of observation and no autocorrelation
# ##Assumption of Normality of Errors

# %% [markdown]
# ##Ri = αi + βi(RM) + εi.........Market model
#
# • Ri = Return of security i
#
# • αi = The return from the asset that is not related to the market’s return. This is “alpha” return from the security
#
# • βi = Beta or the return from the security explained by the market index’s return
#
# • RM = The market index’s return
#
# • εi = Error term for past returns not explained by the regression equation

# %%
#Regression - Market model
model = sm.OLS(y,x_sm)

# %% [markdown]
# #OLS estimation or Ordinary Least square Minimizes the sum of squared errors

# %%
results = model.fit()

# %%
#Regression result
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Return_DRREDDY   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     3.409
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):             0.0714
# Time:                        07:23:37   Log-Likelihood:                 64.314
# No. Observations:                  47   AIC:                            -124.6
# Df Residuals:                      45   BIC:                            -120.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0019      0.010      0.195      0.847      -0.018       0.021
# Return_NIFTY     0.4591      0.249      1.846      0.071      -0.042       0.960
# ==============================================================================
# Omnibus:                        1.078   Durbin-Watson:                   2.110
# Prob(Omnibus):                  0.583   Jarque-Bera (JB):                0.881
# Skew:                          -0.329   Prob(JB):                        0.644
# Kurtosis:                       2.873   Cond. No.                         27.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Beta for Dr. Reddy's Laboratories stock = 0.459 and is not considered to be statistically significant as P value is 0.07 ( > 5% )

# %%
#Regression - Security Characteristic line
returns.info()
sns.regplot(x = 'Return_NIFTY', y = 'Return_DRREDDY', data = returns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 47 entries, 2020-12-01 00:00:00+00:00 to 2024-10-01 00:00:00+00:00
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Return_NIFTY    47 non-null     float64
#  1   Return_DRREDDY  47 non-null     float64
# dtypes: float64(2)
# memory usage: 1.1 KB
# <Axes: xlabel='Return_NIFTY', ylabel='Return_DRREDDY'>

# %%
print('resid', results.resid)
# Out:
# resid Date
# 2020-12-01 00:00:00+00:00    0.037121
# 2021-01-01 00:00:00+00:00   -0.110569
# 2021-02-01 00:00:00+00:00   -0.068006
# 2021-03-01 00:00:00+00:00    0.014311
# 2021-04-01 00:00:00+00:00    0.138815
# 2021-05-01 00:00:00+00:00   -0.002764
# 2021-06-01 00:00:00+00:00    0.014547
# 2021-07-01 00:00:00+00:00   -0.143511
# 2021-08-01 00:00:00+00:00   -0.040246
# 2021-09-01 00:00:00+00:00    0.022592
# 2021-10-01 00:00:00+00:00   -0.049730
# 2021-11-01 00:00:00+00:00    0.019375
# 2021-12-01 00:00:00+00:00    0.036899
# 2022-01-01 00:00:00+00:00   -0.131389
# 2022-02-01 00:00:00+00:00   -0.044931
# 2022-03-01 00:00:00+00:00    0.035085
# 2022-04-01 00:00:00+00:00   -0.028719
# 2022-05-01 00:00:00+00:00    0.066233
# 2022-06-01 00:00:00+00:00    0.025172
# 2022-07-01 00:00:00+00:00   -0.111260
# 2022-08-01 00:00:00+00:00    0.026647
# 2022-09-01 00:00:00+00:00    0.035812
# 2022-10-01 00:00:00+00:00   -0.005335
# 2022-11-01 00:00:00+00:00   -0.007350
# 2022-12-01 00:00:00+00:00   -0.042380
# 2023-01-01 00:00:00+00:00    0.028191
# 2023-02-01 00:00:00+00:00    0.000922
# 2023-03-01 00:00:00+00:00    0.066408
# 2023-04-01 00:00:00+00:00    0.046217
# 2023-05-01 00:00:00+00:00   -0.104087
# 2023-06-01 00:00:00+00:00    0.119546
# 2023-07-01 00:00:00+00:00    0.074562
# 2023-08-01 00:00:00+00:00    0.043747
# 2023-09-01 00:00:00+00:00   -0.012617
# 2023-10-01 00:00:00+00:00   -0.028125
# 2023-11-01 00:00:00+00:00    0.051706
# 2023-12-01 00:00:00+00:00   -0.034855
# 2024-01-01 00:00:00+00:00    0.055482
# 2024-02-01 00:00:00+00:00    0.041682
# 2024-03-01 00:00:00+00:00   -0.051461
# 2024-04-01 00:00:00+00:00    0.000468
# 2024-05-01 00:00:00+00:00   -0.067450
# 2024-06-01 00:00:00+00:00    0.067880
# 2024-07-01 00:00:00+00:00    0.035595
# 2024-08-01 00:00:00+00:00    0.065260
# 2024-09-01 00:00:00+00:00   -0.053140
# 2024-10-01 00:00:00+00:00   -0.032353
# dtype: float64

# %%
#Histogram of residuals
sns.distplot(results.resid)
results.resid.describe()
# Out:
# <ipython-input-75-a89ebdceef41>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(results.resid)
# count    4.700000e+01
# mean    -4.429081e-19
# std      6.225164e-02
# min     -1.435107e-01
# 25%     -4.131299e-02
# 50%      1.431119e-02
# 75%      3.940169e-02
# max      1.388152e-01
# dtype: float64

# %%
#Checking for Homoskedasticity of errors (Assumption requirement of linear regression)
#perform White's test
from statsmodels.stats.diagnostic import het_white
white_test = het_white(results.resid,  results.model.exog)

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 0.5710111895778908, 'Test Statistic p-value': 0.7516341359322213, 'F-Statistic': 0.27056902363322033, 'F-Test p-value': 0.764205358803959}

# %% [markdown]
# #The errors are homoskedastic as per the White test

# %%
#Testing for Normality of errors (Assumption requirement of linear regression)
sm.qqplot(results.resid,line='45',fit=True,dist=stats.norm)

# %%
stats.normaltest(results.resid)
# Out:
# NormaltestResult(statistic=1.0776930371928555, pvalue=0.5834208294740829)

# %% [markdown]
# We can see that since we are plotting the data with the theoretical quantiles of a normal distribution, we are getting almost a straight line, though some points are not exactly on the line.
# The D’Agostino’s K-squared test result suggests that the null hypothesis that the distribution is normal cannot be rejected at 1% significance level.

# %%
#Install required libraries
# !pip install yfinance
import matplotlib.pyplot as plt
import statsmodels.api as sm
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.48)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
#Download stock prices for the security monthly data last 5 years
lupin_df = yf.download('LUPIN.NS',
                      start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo'
)
lupin_df.head()
# Out:
# Price                       Adj Close        Close         High         Low  \
# Ticker                       LUPIN.NS     LUPIN.NS     LUPIN.NS    LUPIN.NS
# Date
# 2020-11-01 00:00:00+00:00  873.751587   891.799988   962.700012  855.349976
# 2020-12-01 00:00:00+00:00  957.080322   976.849976   994.700012  875.000000
# 2021-01-01 00:00:00+00:00  987.208069  1007.599976  1113.300049  975.099976
# 2021-02-01 00:00:00+00:00  997.740479  1018.349976  1109.000000  978.000000
# 2021-03-01 00:00:00+00:00  999.798035  1020.450012  1067.800049  975.000000
#
# Price                             Open    Volume
# Ticker                        LUPIN.NS  LUPIN.NS
# Date
# 2020-11-01 00:00:00+00:00   912.000000  81616832
# 2020-12-01 00:00:00+00:00   894.000000  72915609
# 2021-01-01 00:00:00+00:00   977.950012  70938598
# 2021-02-01 00:00:00+00:00  1008.000000  53866710
# 2021-03-01 00:00:00+00:00  1023.450012  36979644

# %%
#Download Market index closing prices
nifty_df = yf.download('^BSESN',start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo',
)
nifty_df.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  44149.718750  44149.718750  44825.371094
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
#
# Price                               Low          Open  Volume
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  39334.921875  39880.378906  407000
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000

# %%
#Calculate Log returns
nifty_df['Return_NIFTY'] = np.log(nifty_df['Adj Close']/nifty_df['Adj Close'].shift(1))
print(nifty_df['Return_NIFTY'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# 2021-05-01 00:00:00+00:00    0.062671
# 2021-06-01 00:00:00+00:00    0.010444
# 2021-07-01 00:00:00+00:00    0.001982
# 2021-08-01 00:00:00+00:00    0.090230
# 2021-09-01 00:00:00+00:00    0.026981
# 2021-10-01 00:00:00+00:00    0.003049
# 2021-11-01 00:00:00+00:00   -0.038537
# 2021-12-01 00:00:00+00:00    0.020621
# 2022-01-01 00:00:00+00:00   -0.004122
# 2022-02-01 00:00:00+00:00   -0.030930
# 2022-03-01 00:00:00+00:00    0.040440
# 2022-04-01 00:00:00+00:00   -0.026079
# 2022-05-01 00:00:00+00:00   -0.026540
# 2022-06-01 00:00:00+00:00   -0.046930
# 2022-07-01 00:00:00+00:00    0.082357
# 2022-08-01 00:00:00+00:00    0.033593
# 2022-09-01 00:00:00+00:00   -0.036086
# 2022-10-01 00:00:00+00:00    0.056198
# 2022-11-01 00:00:00+00:00    0.038004
# 2022-12-01 00:00:00+00:00   -0.036456
# 2023-01-01 00:00:00+00:00   -0.021445
# 2023-02-01 00:00:00+00:00   -0.009919
# 2023-03-01 00:00:00+00:00    0.000498
# 2023-04-01 00:00:00+00:00    0.035322
# 2023-05-01 00:00:00+00:00    0.024405
# 2023-06-01 00:00:00+00:00    0.032928
# 2023-07-01 00:00:00+00:00    0.027570
# 2023-08-01 00:00:00+00:00   -0.025828
# 2023-09-01 00:00:00+00:00    0.015261
# 2023-10-01 00:00:00+00:00   -0.030125
# 2023-11-01 00:00:00+00:00    0.047593
# 2023-12-01 00:00:00+00:00    0.075477
# 2024-01-01 00:00:00+00:00   -0.006780
# 2024-02-01 00:00:00+00:00    0.010373
# 2024-03-01 00:00:00+00:00    0.015752
# 2024-04-01 00:00:00+00:00    0.011225
# 2024-05-01 00:00:00+00:00   -0.007026
# 2024-06-01 00:00:00+00:00    0.066320
# 2024-07-01 00:00:00+00:00    0.033698
# 2024-08-01 00:00:00+00:00    0.007610
# 2024-09-01 00:00:00+00:00    0.023209
# 2024-10-01 00:00:00+00:00   -0.060019
# Name: Return_NIFTY, dtype: float64

# %%
nifty_df['Return_NIFTY'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df1 = nifty_df.dropna(axis=0)
nifty_df1.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
# 2021-04-01 00:00:00+00:00  48782.359375  48782.359375  50375.769531
#
# Price                               Low          Open  Volume Return_NIFTY
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400     0.078420
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300    -0.031172
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900     0.059024
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000     0.008299
# 2021-04-01 00:00:00+00:00  47204.500000  49868.531250  249700    -0.014789

# %%
#Caclulate log returns
lupin_df['Return_LUPIN'] = np.log(lupin_df['Adj Close']/lupin_df['Adj Close'].shift(1))
print(lupin_df['Return_LUPIN'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.091091
# 2021-01-01 00:00:00+00:00    0.030994
# 2021-02-01 00:00:00+00:00    0.010612
# 2021-03-01 00:00:00+00:00    0.002060
# 2021-04-01 00:00:00+00:00    0.046948
# 2021-05-01 00:00:00+00:00    0.131250
# 2021-06-01 00:00:00+00:00   -0.059462
# 2021-07-01 00:00:00+00:00   -0.036964
# 2021-08-01 00:00:00+00:00   -0.139516
# 2021-09-01 00:00:00+00:00   -0.006546
# 2021-10-01 00:00:00+00:00   -0.030624
# 2021-11-01 00:00:00+00:00   -0.042611
# 2021-12-01 00:00:00+00:00    0.072342
# 2022-01-01 00:00:00+00:00   -0.045897
# 2022-02-01 00:00:00+00:00   -0.196830
# 2022-03-01 00:00:00+00:00    0.001608
# 2022-04-01 00:00:00+00:00   -0.003218
# 2022-05-01 00:00:00+00:00   -0.185456
# 2022-06-01 00:00:00+00:00   -0.012444
# 2022-07-01 00:00:00+00:00    0.052839
# 2022-08-01 00:00:00+00:00    0.044281
# 2022-09-01 00:00:00+00:00    0.015939
# 2022-10-01 00:00:00+00:00    0.027779
# 2022-11-01 00:00:00+00:00    0.091662
# 2022-12-01 00:00:00+00:00   -0.043212
# 2023-01-01 00:00:00+00:00    0.004895
# 2023-02-01 00:00:00+00:00   -0.111892
# 2023-03-01 00:00:00+00:00   -0.016595
# 2023-04-01 00:00:00+00:00    0.090053
# 2023-05-01 00:00:00+00:00    0.125660
# 2023-06-01 00:00:00+00:00    0.115225
# 2023-07-01 00:00:00+00:00    0.087653
# 2023-08-01 00:00:00+00:00    0.112317
# 2023-09-01 00:00:00+00:00    0.064718
# 2023-10-01 00:00:00+00:00   -0.037492
# 2023-11-01 00:00:00+00:00    0.126984
# 2023-12-01 00:00:00+00:00    0.032301
# 2024-01-01 00:00:00+00:00    0.129161
# 2024-02-01 00:00:00+00:00    0.074049
# 2024-03-01 00:00:00+00:00   -0.002625
# 2024-04-01 00:00:00+00:00    0.017838
# 2024-05-01 00:00:00+00:00   -0.039250
# 2024-06-01 00:00:00+00:00    0.024222
# 2024-07-01 00:00:00+00:00    0.164812
# 2024-08-01 00:00:00+00:00    0.162868
# 2024-09-01 00:00:00+00:00   -0.022161
# 2024-10-01 00:00:00+00:00   -0.001896
# Name: Return_LUPIN, dtype: float64

# %%
lupin_df1 = lupin_df.dropna(axis=0)
lupin_df1.head()
# Out:
# Price                        Adj Close        Close         High          Low  \
# Ticker                        LUPIN.NS     LUPIN.NS     LUPIN.NS     LUPIN.NS
# Date
# 2020-12-01 00:00:00+00:00   957.080322   976.849976   994.700012   875.000000
# 2021-01-01 00:00:00+00:00   987.208069  1007.599976  1113.300049   975.099976
# 2021-02-01 00:00:00+00:00   997.740479  1018.349976  1109.000000   978.000000
# 2021-03-01 00:00:00+00:00   999.798035  1020.450012  1067.800049   975.000000
# 2021-04-01 00:00:00+00:00  1047.855347  1069.500000  1106.900024  1007.250000
#
# Price                             Open    Volume Return_LUPIN
# Ticker                        LUPIN.NS  LUPIN.NS
# Date
# 2020-12-01 00:00:00+00:00   894.000000  72915609     0.091091
# 2021-01-01 00:00:00+00:00   977.950012  70938598     0.030994
# 2021-02-01 00:00:00+00:00  1008.000000  53866710     0.010612
# 2021-03-01 00:00:00+00:00  1023.450012  36979644     0.002060
# 2021-04-01 00:00:00+00:00  1033.000000  42919782     0.046948

# %%
lupin_df['Return_LUPIN'].plot(figsize=(8,5))
plt.show()

# %%
lupin_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
lupin_df1_returns = lupin_df1['Return_LUPIN']
lupin_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.091091
# 2021-01-01 00:00:00+00:00    0.030994
# 2021-02-01 00:00:00+00:00    0.010612
# 2021-03-01 00:00:00+00:00    0.002060
# 2021-04-01 00:00:00+00:00    0.046948
# Name: Return_LUPIN, dtype: float64

# %%
nifty_df1_returns = nifty_df1['Return_NIFTY']
nifty_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# Name: Return_NIFTY, dtype: float64

# %%
returns = pd.merge(nifty_df1_returns,lupin_df1_returns,how='inner',on='Date')
returns.head()
returns.describe()
# Out:
#        Return_NIFTY  Return_LUPIN
# count     47.000000     47.000000
# mean       0.012485      0.019521
# std        0.037319      0.081642
# min       -0.060019     -0.196830
# 25%       -0.018117     -0.026393
# 50%        0.010444      0.015939
# 75%        0.034510      0.080851
# max        0.090230      0.164812

# %%
sns.pairplot(returns)
plt.show()

# %%
sns.heatmap(returns.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
x = returns['Return_NIFTY']
y = returns['Return_LUPIN']
x_sm = sm.add_constant(x)

# %% [markdown]
# #Assumptions of OLS regression
# ##A linear relationship between the dependent and independent variables - The linear regression model is linear in parameters
# ##The independent variables are not highly correlated with each other - no multicollinearity
# ##The variance of the residuals is constant - no heteroskedasticity
# ##Random sampling of observation and no autocorrelation
# ##Assumption of Normality of Errors

# %% [markdown]
# ##Ri = αi + βi(RM) + εi.........Market model
#
# • Ri = Return of security i
#
# • αi = The return from the asset that is not related to the market’s return. This is “alpha” return from the security
#
# • βi = Beta or the return from the security explained by the market index’s return
#
# • RM = The market index’s return
#
# • εi = Error term for past returns not explained by the regression equation

# %%
#Regression - Market model
model = sm.OLS(y,x_sm)

# %% [markdown]
# #OLS estimation or Ordinary Least square Minimizes the sum of squared errors

# %%
results = model.fit()

# %%
#Regression result
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Return_LUPIN   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     5.373
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):             0.0251
# Time:                        07:35:18   Log-Likelihood:                 54.220
# No. Observations:                  47   AIC:                            -104.4
# Df Residuals:                      45   BIC:                            -100.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0106      0.012      0.882      0.382      -0.014       0.035
# Return_NIFTY     0.7145      0.308      2.318      0.025       0.094       1.335
# ==============================================================================
# Omnibus:                        4.973   Durbin-Watson:                   1.543
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                3.776
# Skew:                          -0.582   Prob(JB):                        0.151
# Kurtosis:                       3.758   Cond. No.                         27.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Beta for LUPIN stock = 0.7145 and is statistically significant as P value is less than 0.05 i.e. 0.025 (null hypothesis is rejected).

# %%
#Regression - Security Characteristic line
returns.info()
sns.regplot(x = 'Return_NIFTY', y = 'Return_LUPIN', data = returns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 47 entries, 2020-12-01 00:00:00+00:00 to 2024-10-01 00:00:00+00:00
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Return_NIFTY  47 non-null     float64
#  1   Return_LUPIN  47 non-null     float64
# dtypes: float64(2)
# memory usage: 1.1 KB
# <Axes: xlabel='Return_NIFTY', ylabel='Return_LUPIN'>

# %%
print('resid', results.resid)
# Out:
# resid Date
# 2020-12-01 00:00:00+00:00    0.024459
# 2021-01-01 00:00:00+00:00    0.042666
# 2021-02-01 00:00:00+00:00   -0.042161
# 2021-03-01 00:00:00+00:00   -0.014470
# 2021-04-01 00:00:00+00:00    0.046914
# 2021-05-01 00:00:00+00:00    0.075870
# 2021-06-01 00:00:00+00:00   -0.077525
# 2021-07-01 00:00:00+00:00   -0.048980
# 2021-08-01 00:00:00+00:00   -0.214587
# 2021-09-01 00:00:00+00:00   -0.036425
# 2021-10-01 00:00:00+00:00   -0.043403
# 2021-11-01 00:00:00+00:00   -0.025676
# 2021-12-01 00:00:00+00:00    0.047008
# 2022-01-01 00:00:00+00:00   -0.053552
# 2022-02-01 00:00:00+00:00   -0.185331
# 2022-03-01 00:00:00+00:00   -0.037887
# 2022-04-01 00:00:00+00:00    0.004815
# 2022-05-01 00:00:00+00:00   -0.177093
# 2022-06-01 00:00:00+00:00    0.010488
# 2022-07-01 00:00:00+00:00   -0.016606
# 2022-08-01 00:00:00+00:00    0.009678
# 2022-09-01 00:00:00+00:00    0.031122
# 2022-10-01 00:00:00+00:00   -0.022975
# 2022-11-01 00:00:00+00:00    0.053907
# 2022-12-01 00:00:00+00:00   -0.027765
# 2023-01-01 00:00:00+00:00    0.009617
# 2023-02-01 00:00:00+00:00   -0.115405
# 2023-03-01 00:00:00+00:00   -0.027551
# 2023-04-01 00:00:00+00:00    0.054215
# 2023-05-01 00:00:00+00:00    0.097623
# 2023-06-01 00:00:00+00:00    0.081097
# 2023-07-01 00:00:00+00:00    0.057353
# 2023-08-01 00:00:00+00:00    0.120171
# 2023-09-01 00:00:00+00:00    0.043213
# 2023-10-01 00:00:00+00:00   -0.026568
# 2023-11-01 00:00:00+00:00    0.082378
# 2023-12-01 00:00:00+00:00   -0.032228
# 2024-01-01 00:00:00+00:00    0.123406
# 2024-02-01 00:00:00+00:00    0.056037
# 2024-03-01 00:00:00+00:00   -0.024480
# 2024-04-01 00:00:00+00:00   -0.000783
# 2024-05-01 00:00:00+00:00   -0.044830
# 2024-06-01 00:00:00+00:00   -0.033765
# 2024-07-01 00:00:00+00:00    0.130135
# 2024-08-01 00:00:00+00:00    0.146831
# 2024-09-01 00:00:00+00:00   -0.049345
# 2024-10-01 00:00:00+00:00    0.030388
# dtype: float64

# %%
#Histogram of residuals
sns.distplot(results.resid)
results.resid.describe()
# Out:
# <ipython-input-153-a89ebdceef41>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(results.resid)
# count    4.700000e+01
# mean    -1.550178e-18
# std      7.716490e-02
# min     -2.145866e-01
# 25%     -3.715597e-02
# 50%     -7.825424e-04
# 75%      5.045742e-02
# max      1.468307e-01
# dtype: float64

# %%
#Checking for Homoskedasticity of errors (Assumption requirement of linear regression)
#perform White's test
from statsmodels.stats.diagnostic import het_white
white_test = het_white(results.resid,  results.model.exog)

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 1.5758277308713415, 'Test Statistic p-value': 0.45479256484033126, 'F-Statistic': 0.7632106067616955, 'F-Test p-value': 0.47223874321513637}

# %% [markdown]
# #The errors are homoskedastic as per the White test

# %%
#Testing for Normality of errors (Assumption requirement of linear regression)
sm.qqplot(results.resid,line='45',fit=True,dist=stats.norm)

# %%
stats.normaltest(results.resid)
# Out:
# NormaltestResult(statistic=4.972813372594064, pvalue=0.08320842399861686)

# %% [markdown]
# We can see that since we are plotting the data with the theoretical quantiles of a normal distribution, we are getting almost a straight line, though some points are not exactly on the line.
# The D’Agostino’s K-squared test result suggests that the null hypothesis that the distribution is normal cannot be rejected at 1% significance level.

# %%
#Install required libraries
# !pip install yfinance
import matplotlib.pyplot as plt
import statsmodels.api as sm
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.48)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
#Download stock prices for the security monthly data last 5 years
Aurobindo_df = yf.download('AUROPHARMA.NS',
                      start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo'
)
Aurobindo_df.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                    AUROPHARMA.NS AUROPHARMA.NS AUROPHARMA.NS
# Date
# 2020-11-01 00:00:00+00:00    843.724731    868.549988    893.500000
# 2020-12-01 00:00:00+00:00    896.311218    921.299988    943.500000
# 2021-01-01 00:00:00+00:00    880.696655    905.250000   1023.700012
# 2021-02-01 00:00:00+00:00    832.004028    855.200012    980.000000
# 2021-03-01 00:00:00+00:00    858.846008    881.299988    889.000000
#
# Price                               Low          Open        Volume
# Ticker                    AUROPHARMA.NS AUROPHARMA.NS AUROPHARMA.NS
# Date
# 2020-11-01 00:00:00+00:00    753.000000    774.000000      83035804
# 2020-12-01 00:00:00+00:00    801.099976    876.250000      62820932
# 2021-01-01 00:00:00+00:00    880.150024    923.700012      71930147
# 2021-02-01 00:00:00+00:00    837.000000    912.000000      60510083
# 2021-03-01 00:00:00+00:00    797.299988    855.099976      41429289

# %%
#Download Market index closing prices
nifty_df = yf.download('^BSESN',start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo',
)
nifty_df.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  44149.718750  44149.718750  44825.371094
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
#
# Price                               Low          Open  Volume
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  39334.921875  39880.378906  407000
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000

# %%
#Calculate Log returns
nifty_df['Return_NIFTY'] = np.log(nifty_df['Adj Close']/nifty_df['Adj Close'].shift(1))
print(nifty_df['Return_NIFTY'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# 2021-05-01 00:00:00+00:00    0.062671
# 2021-06-01 00:00:00+00:00    0.010444
# 2021-07-01 00:00:00+00:00    0.001982
# 2021-08-01 00:00:00+00:00    0.090230
# 2021-09-01 00:00:00+00:00    0.026981
# 2021-10-01 00:00:00+00:00    0.003049
# 2021-11-01 00:00:00+00:00   -0.038537
# 2021-12-01 00:00:00+00:00    0.020621
# 2022-01-01 00:00:00+00:00   -0.004122
# 2022-02-01 00:00:00+00:00   -0.030930
# 2022-03-01 00:00:00+00:00    0.040440
# 2022-04-01 00:00:00+00:00   -0.026079
# 2022-05-01 00:00:00+00:00   -0.026540
# 2022-06-01 00:00:00+00:00   -0.046930
# 2022-07-01 00:00:00+00:00    0.082357
# 2022-08-01 00:00:00+00:00    0.033593
# 2022-09-01 00:00:00+00:00   -0.036086
# 2022-10-01 00:00:00+00:00    0.056198
# 2022-11-01 00:00:00+00:00    0.038004
# 2022-12-01 00:00:00+00:00   -0.036456
# 2023-01-01 00:00:00+00:00   -0.021445
# 2023-02-01 00:00:00+00:00   -0.009919
# 2023-03-01 00:00:00+00:00    0.000498
# 2023-04-01 00:00:00+00:00    0.035322
# 2023-05-01 00:00:00+00:00    0.024405
# 2023-06-01 00:00:00+00:00    0.032928
# 2023-07-01 00:00:00+00:00    0.027570
# 2023-08-01 00:00:00+00:00   -0.025828
# 2023-09-01 00:00:00+00:00    0.015261
# 2023-10-01 00:00:00+00:00   -0.030125
# 2023-11-01 00:00:00+00:00    0.047593
# 2023-12-01 00:00:00+00:00    0.075477
# 2024-01-01 00:00:00+00:00   -0.006780
# 2024-02-01 00:00:00+00:00    0.010373
# 2024-03-01 00:00:00+00:00    0.015752
# 2024-04-01 00:00:00+00:00    0.011225
# 2024-05-01 00:00:00+00:00   -0.007026
# 2024-06-01 00:00:00+00:00    0.066320
# 2024-07-01 00:00:00+00:00    0.033698
# 2024-08-01 00:00:00+00:00    0.007610
# 2024-09-01 00:00:00+00:00    0.023209
# 2024-10-01 00:00:00+00:00   -0.060019
# Name: Return_NIFTY, dtype: float64

# %%
nifty_df['Return_NIFTY'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df1 = nifty_df.dropna(axis=0)
nifty_df1.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
# 2021-04-01 00:00:00+00:00  48782.359375  48782.359375  50375.769531
#
# Price                               Low          Open  Volume Return_NIFTY
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400     0.078420
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300    -0.031172
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900     0.059024
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000     0.008299
# 2021-04-01 00:00:00+00:00  47204.500000  49868.531250  249700    -0.014789

# %%
#Caclulate log returns
Aurobindo_df['Return_AUROPHARMA'] = np.log(Aurobindo_df['Adj Close']/Aurobindo_df['Adj Close'].shift(1))
print(Aurobindo_df['Return_AUROPHARMA'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.060461
# 2021-01-01 00:00:00+00:00   -0.017574
# 2021-02-01 00:00:00+00:00   -0.056876
# 2021-03-01 00:00:00+00:00    0.031752
# 2021-04-01 00:00:00+00:00    0.107021
# 2021-05-01 00:00:00+00:00    0.017284
# 2021-06-01 00:00:00+00:00   -0.033368
# 2021-07-01 00:00:00+00:00   -0.051664
# 2021-08-01 00:00:00+00:00   -0.231332
# 2021-09-01 00:00:00+00:00   -0.001295
# 2021-10-01 00:00:00+00:00   -0.050147
# 2021-11-01 00:00:00+00:00   -0.043130
# 2021-12-01 00:00:00+00:00    0.108553
# 2022-01-01 00:00:00+00:00   -0.146227
# 2022-02-01 00:00:00+00:00   -0.014607
# 2022-03-01 00:00:00+00:00    0.069185
# 2022-04-01 00:00:00+00:00   -0.060901
# 2022-05-01 00:00:00+00:00   -0.169825
# 2022-06-01 00:00:00+00:00   -0.033915
# 2022-07-01 00:00:00+00:00    0.072531
# 2022-08-01 00:00:00+00:00   -0.002929
# 2022-09-01 00:00:00+00:00   -0.065933
# 2022-10-01 00:00:00+00:00    0.052551
# 2022-11-01 00:00:00+00:00   -0.141059
# 2022-12-01 00:00:00+00:00   -0.064175
# 2023-01-01 00:00:00+00:00   -0.071269
# 2023-02-01 00:00:00+00:00    0.125552
# 2023-03-01 00:00:00+00:00    0.119252
# 2023-04-01 00:00:00+00:00    0.174701
# 2023-05-01 00:00:00+00:00    0.065247
# 2023-06-01 00:00:00+00:00    0.099291
# 2023-07-01 00:00:00+00:00    0.122637
# 2023-08-01 00:00:00+00:00    0.009381
# 2023-09-01 00:00:00+00:00    0.096788
# 2023-10-01 00:00:00+00:00   -0.073565
# 2023-11-01 00:00:00+00:00    0.203817
# 2023-12-01 00:00:00+00:00    0.042930
# 2024-01-01 00:00:00+00:00    0.059452
# 2024-02-01 00:00:00+00:00   -0.112397
# 2024-03-01 00:00:00+00:00    0.058760
# 2024-04-01 00:00:00+00:00    0.057771
# 2024-05-01 00:00:00+00:00    0.027532
# 2024-06-01 00:00:00+00:00    0.018302
# 2024-07-01 00:00:00+00:00    0.171937
# 2024-08-01 00:00:00+00:00    0.090121
# 2024-09-01 00:00:00+00:00   -0.071778
# 2024-10-01 00:00:00+00:00   -0.044947
# Name: Return_AUROPHARMA, dtype: float64

# %%
Aurobindo_df1 = Aurobindo_df.dropna(axis=0)
Aurobindo_df1.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                    AUROPHARMA.NS AUROPHARMA.NS AUROPHARMA.NS
# Date
# 2020-12-01 00:00:00+00:00    896.311218    921.299988    943.500000
# 2021-01-01 00:00:00+00:00    880.696655    905.250000   1023.700012
# 2021-02-01 00:00:00+00:00    832.004028    855.200012    980.000000
# 2021-03-01 00:00:00+00:00    858.846008    881.299988    889.000000
# 2021-04-01 00:00:00+00:00    955.859680    980.849976   1015.000000
#
# Price                               Low          Open        Volume  \
# Ticker                    AUROPHARMA.NS AUROPHARMA.NS AUROPHARMA.NS
# Date
# 2020-12-01 00:00:00+00:00    801.099976    876.250000      62820932
# 2021-01-01 00:00:00+00:00    880.150024    923.700012      71930147
# 2021-02-01 00:00:00+00:00    837.000000    912.000000      60510083
# 2021-03-01 00:00:00+00:00    797.299988    855.099976      41429289
# 2021-04-01 00:00:00+00:00    866.349976    879.000000      56757756
#
# Price                     Return_AUROPHARMA
# Ticker
# Date
# 2020-12-01 00:00:00+00:00          0.060461
# 2021-01-01 00:00:00+00:00         -0.017574
# 2021-02-01 00:00:00+00:00         -0.056876
# 2021-03-01 00:00:00+00:00          0.031752
# 2021-04-01 00:00:00+00:00          0.107021

# %%
Aurobindo_df['Return_AUROPHARMA'].plot(figsize=(8,5))
plt.show()

# %%
Aurobindo_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
Aurobindo_df1_returns = Aurobindo_df1['Return_AUROPHARMA']
Aurobindo_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.060461
# 2021-01-01 00:00:00+00:00   -0.017574
# 2021-02-01 00:00:00+00:00   -0.056876
# 2021-03-01 00:00:00+00:00    0.031752
# 2021-04-01 00:00:00+00:00    0.107021
# Name: Return_AUROPHARMA, dtype: float64

# %%
nifty_df1_returns = nifty_df1['Return_NIFTY']
nifty_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# Name: Return_NIFTY, dtype: float64

# %%
returns = pd.merge(nifty_df1_returns,Aurobindo_df1_returns,how='inner',on='Date')
returns.head()
returns.describe()
# Out:
#        Return_NIFTY  Return_AUROPHARMA
# count     47.000000          47.000000
# mean       0.012485           0.010721
# std        0.037319           0.093992
# min       -0.060019          -0.231332
# 25%       -0.018117          -0.054270
# 50%        0.010444           0.017284
# 75%        0.034510           0.070858
# max        0.090230           0.203817

# %%
sns.pairplot(returns)
plt.show()

# %%
sns.heatmap(returns.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
x = returns['Return_NIFTY']
y = returns['Return_AUROPHARMA']
x_sm = sm.add_constant(x)

# %% [markdown]
# #Assumptions of OLS regression
# ##A linear relationship between the dependent and independent variables - The linear regression model is linear in parameters
# ##The independent variables are not highly correlated with each other - no multicollinearity
# ##The variance of the residuals is constant - no heteroskedasticity
# ##Random sampling of observation and no autocorrelation
# ##Assumption of Normality of Errors

# %% [markdown]
# ##Ri = αi + βi(RM) + εi.........Market model
#
# • Ri = Return of security i
#
# • αi = The return from the asset that is not related to the market’s return. This is “alpha” return from the security
#
# • βi = Beta or the return from the security explained by the market index’s return
#
# • RM = The market index’s return
#
# • εi = Error term for past returns not explained by the regression equation

# %%
#Regression - Market model
model = sm.OLS(y,x_sm)

# %% [markdown]
# #OLS estimation or Ordinary Least square Minimizes the sum of squared errors

# %%
results = model.fit()

# %%
#Regression result
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Return_AUROPHARMA   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     2.527
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):              0.119
# Time:                        07:46:40   Log-Likelihood:                 46.233
# No. Observations:                  47   AIC:                            -88.47
# Df Residuals:                      45   BIC:                            -84.76
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0035      0.014      0.244      0.809      -0.025       0.032
# Return_NIFTY     0.5807      0.365      1.590      0.119      -0.155       1.317
# ==============================================================================
# Omnibus:                        4.739   Durbin-Watson:                   1.749
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                3.563
# Skew:                          -0.545   Prob(JB):                        0.168
# Kurtosis:                       3.793   Cond. No.                         27.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Beta for AUROPHARMA stock = 0.58 and is not statistically significant as P value is 0.119

# %%
#Regression - Security Characteristic line
returns.info()
sns.regplot(x = 'Return_NIFTY', y = 'Return_AUROPHARMA', data = returns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 47 entries, 2020-12-01 00:00:00+00:00 to 2024-10-01 00:00:00+00:00
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Return_NIFTY       47 non-null     float64
#  1   Return_AUROPHARMA  47 non-null     float64
# dtypes: float64(2)
# memory usage: 1.1 KB
# <Axes: xlabel='Return_NIFTY', ylabel='Return_AUROPHARMA'>

# %%
print('resid', results.resid)
# Out:
# resid Date
# 2020-12-01 00:00:00+00:00    0.011449
# 2021-01-01 00:00:00+00:00   -0.002942
# 2021-02-01 00:00:00+00:00   -0.094625
# 2021-03-01 00:00:00+00:00    0.023462
# 2021-04-01 00:00:00+00:00    0.112139
# 2021-05-01 00:00:00+00:00   -0.022583
# 2021-06-01 00:00:00+00:00   -0.042904
# 2021-07-01 00:00:00+00:00   -0.056286
# 2021-08-01 00:00:00+00:00   -0.287203
# 2021-09-01 00:00:00+00:00   -0.020435
# 2021-10-01 00:00:00+00:00   -0.055388
# 2021-11-01 00:00:00+00:00   -0.024221
# 2021-12-01 00:00:00+00:00    0.093107
# 2022-01-01 00:00:00+00:00   -0.147304
# 2022-02-01 00:00:00+00:00   -0.000116
# 2022-03-01 00:00:00+00:00    0.042230
# 2022-04-01 00:00:00+00:00   -0.049227
# 2022-05-01 00:00:00+00:00   -0.157884
# 2022-06-01 00:00:00+00:00   -0.010132
# 2022-07-01 00:00:00+00:00    0.021232
# 2022-08-01 00:00:00+00:00   -0.025909
# 2022-09-01 00:00:00+00:00   -0.048448
# 2022-10-01 00:00:00+00:00    0.016444
# 2022-11-01 00:00:00+00:00   -0.166600
# 2022-12-01 00:00:00+00:00   -0.046475
# 2023-01-01 00:00:00+00:00   -0.062286
# 2023-02-01 00:00:00+00:00    0.127842
# 2023-03-01 00:00:00+00:00    0.115492
# 2023-04-01 00:00:00+00:00    0.150717
# 2023-05-01 00:00:00+00:00    0.047603
# 2023-06-01 00:00:00+00:00    0.076698
# 2023-07-01 00:00:00+00:00    0.103155
# 2023-08-01 00:00:00+00:00    0.020910
# 2023-09-01 00:00:00+00:00    0.084454
# 2023-10-01 00:00:00+00:00   -0.059542
# 2023-11-01 00:00:00+00:00    0.172707
# 2023-12-01 00:00:00+00:00   -0.004373
# 2024-01-01 00:00:00+00:00    0.059918
# 2024-02-01 00:00:00+00:00   -0.121892
# 2024-03-01 00:00:00+00:00    0.046141
# 2024-04-01 00:00:00+00:00    0.047781
# 2024-05-01 00:00:00+00:00    0.028142
# 2024-06-01 00:00:00+00:00   -0.023684
# 2024-07-01 00:00:00+00:00    0.148897
# 2024-08-01 00:00:00+00:00    0.082231
# 2024-09-01 00:00:00+00:00   -0.088727
# 2024-10-01 00:00:00+00:00   -0.013562
# dtype: float64

# %%
#Histogram of residuals
sns.distplot(results.resid)
results.resid.describe()
# Out:
# <ipython-input-180-a89ebdceef41>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(results.resid)
# count    4.700000e+01
# mean    -3.543265e-18
# std      9.145977e-02
# min     -2.872031e-01
# 25%     -4.883707e-02
# 50%     -2.942396e-03
# 75%      5.384945e-02
# max      1.727073e-01
# dtype: float64

# %%
#Checking for Homoskedasticity of errors (Assumption requirement of linear regression)
#perform White's test
from statsmodels.stats.diagnostic import het_white
white_test = het_white(results.resid,  results.model.exog)

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 5.051437062843696, 'Test Statistic p-value': 0.0800008090350034, 'F-Statistic': 2.649235339695643, 'F-Test p-value': 0.08196398210467996}

# %% [markdown]
# #The errors are homoskedastic as per the White test

# %%
#Testing for Normality of errors (Assumption requirement of linear regression)
sm.qqplot(results.resid,line='45',fit=True,dist=stats.norm)

# %%
stats.normaltest(results.resid)
# Out:
# NormaltestResult(statistic=4.73889199324754, pvalue=0.09353252926421861)

# %% [markdown]
# We can see that since we are plotting the data with the theoretical quantiles of a normal distribution, we are getting almost a straight line, though some points are not exactly on the line.
# The D’Agostino’s K-squared test result suggests that the null hypothesis that the distribution is normal cannot be rejected at 1% significance level.

# %%
#Install required libraries
# !pip install yfinance
import matplotlib.pyplot as plt
import statsmodels.api as sm
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.48)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
#Download stock prices for the security monthly data last 5 years
TORNTPHARM_df = yf.download('TORNTPHARM.NS',
                      start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo'
)
TORNTPHARM_df.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                    TORNTPHARM.NS TORNTPHARM.NS TORNTPHARM.NS
# Date
# 2020-11-01 00:00:00+00:00   1245.039673   1307.550049   1377.949951
# 2020-12-01 00:00:00+00:00   1334.355225   1401.349976   1428.275024
# 2021-01-01 00:00:00+00:00   1241.730591   1304.074951   1452.500000
# 2021-02-01 00:00:00+00:00   1156.057251   1214.099976   1401.449951
# 2021-03-01 00:00:00+00:00   1221.075195   1272.525024   1278.474976
#
# Price                               Low          Open        Volume
# Ticker                    TORNTPHARM.NS TORNTPHARM.NS TORNTPHARM.NS
# Date
# 2020-11-01 00:00:00+00:00   1209.375000   1283.000000      23216904
# 2020-12-01 00:00:00+00:00   1291.699951   1315.000000      18575692
# 2021-01-01 00:00:00+00:00   1285.650024   1401.449951      14160266
# 2021-02-01 00:00:00+00:00   1200.699951   1312.949951      21001760
# 2021-03-01 00:00:00+00:00   1155.550049   1203.400024      10866550

# %%
#Download Market index closing prices
nifty_df = yf.download('^BSESN',start='2020-11-01',
                      end='2024-10-31',
                      progress=False,interval ='1mo',
)
nifty_df.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  44149.718750  44149.718750  44825.371094
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
#
# Price                               Low          Open  Volume
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-11-01 00:00:00+00:00  39334.921875  39880.378906  407000
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000

# %%
#Calculate Log returns
nifty_df['Return_NIFTY'] = np.log(nifty_df['Adj Close']/nifty_df['Adj Close'].shift(1))
print(nifty_df['Return_NIFTY'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# 2021-05-01 00:00:00+00:00    0.062671
# 2021-06-01 00:00:00+00:00    0.010444
# 2021-07-01 00:00:00+00:00    0.001982
# 2021-08-01 00:00:00+00:00    0.090230
# 2021-09-01 00:00:00+00:00    0.026981
# 2021-10-01 00:00:00+00:00    0.003049
# 2021-11-01 00:00:00+00:00   -0.038537
# 2021-12-01 00:00:00+00:00    0.020621
# 2022-01-01 00:00:00+00:00   -0.004122
# 2022-02-01 00:00:00+00:00   -0.030930
# 2022-03-01 00:00:00+00:00    0.040440
# 2022-04-01 00:00:00+00:00   -0.026079
# 2022-05-01 00:00:00+00:00   -0.026540
# 2022-06-01 00:00:00+00:00   -0.046930
# 2022-07-01 00:00:00+00:00    0.082357
# 2022-08-01 00:00:00+00:00    0.033593
# 2022-09-01 00:00:00+00:00   -0.036086
# 2022-10-01 00:00:00+00:00    0.056198
# 2022-11-01 00:00:00+00:00    0.038004
# 2022-12-01 00:00:00+00:00   -0.036456
# 2023-01-01 00:00:00+00:00   -0.021445
# 2023-02-01 00:00:00+00:00   -0.009919
# 2023-03-01 00:00:00+00:00    0.000498
# 2023-04-01 00:00:00+00:00    0.035322
# 2023-05-01 00:00:00+00:00    0.024405
# 2023-06-01 00:00:00+00:00    0.032928
# 2023-07-01 00:00:00+00:00    0.027570
# 2023-08-01 00:00:00+00:00   -0.025828
# 2023-09-01 00:00:00+00:00    0.015261
# 2023-10-01 00:00:00+00:00   -0.030125
# 2023-11-01 00:00:00+00:00    0.047593
# 2023-12-01 00:00:00+00:00    0.075477
# 2024-01-01 00:00:00+00:00   -0.006780
# 2024-02-01 00:00:00+00:00    0.010373
# 2024-03-01 00:00:00+00:00    0.015752
# 2024-04-01 00:00:00+00:00    0.011225
# 2024-05-01 00:00:00+00:00   -0.007026
# 2024-06-01 00:00:00+00:00    0.066320
# 2024-07-01 00:00:00+00:00    0.033698
# 2024-08-01 00:00:00+00:00    0.007610
# 2024-09-01 00:00:00+00:00    0.023209
# 2024-10-01 00:00:00+00:00   -0.060019
# Name: Return_NIFTY, dtype: float64

# %%
nifty_df['Return_NIFTY'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
nifty_df1 = nifty_df.dropna(axis=0)
nifty_df1.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                           ^BSESN        ^BSESN        ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  47751.328125  47751.328125  47896.968750
# 2021-01-01 00:00:00+00:00  46285.769531  46285.769531  50184.011719
# 2021-02-01 00:00:00+00:00  49099.988281  49099.988281  52516.761719
# 2021-03-01 00:00:00+00:00  49509.148438  49509.148438  51821.839844
# 2021-04-01 00:00:00+00:00  48782.359375  48782.359375  50375.769531
#
# Price                               Low          Open  Volume Return_NIFTY
# Ticker                           ^BSESN        ^BSESN  ^BSESN
# Date
# 2020-12-01 00:00:00+00:00  44118.101562  44435.828125  390400     0.078420
# 2021-01-01 00:00:00+00:00  46160.460938  47785.281250  424300    -0.031172
# 2021-02-01 00:00:00+00:00  46433.648438  46617.949219  439900     0.059024
# 2021-03-01 00:00:00+00:00  48236.351562  49747.710938  270000     0.008299
# 2021-04-01 00:00:00+00:00  47204.500000  49868.531250  249700    -0.014789

# %%
#Caclulate log returns
TORNTPHARM_df['Return_TORNTPHARM'] = np.log(TORNTPHARM_df['Adj Close']/TORNTPHARM_df['Adj Close'].shift(1))
print(TORNTPHARM_df['Return_TORNTPHARM'])
# Out:
# Date
# 2020-11-01 00:00:00+00:00         NaN
# 2020-12-01 00:00:00+00:00    0.069281
# 2021-01-01 00:00:00+00:00   -0.071942
# 2021-02-01 00:00:00+00:00   -0.071491
# 2021-03-01 00:00:00+00:00    0.054716
# 2021-04-01 00:00:00+00:00   -0.014166
# 2021-05-01 00:00:00+00:00    0.088467
# 2021-06-01 00:00:00+00:00    0.056812
# 2021-07-01 00:00:00+00:00    0.061977
# 2021-08-01 00:00:00+00:00    0.011268
# 2021-09-01 00:00:00+00:00   -0.006590
# 2021-10-01 00:00:00+00:00   -0.075752
# 2021-11-01 00:00:00+00:00    0.061570
# 2021-12-01 00:00:00+00:00    0.074839
# 2022-01-01 00:00:00+00:00   -0.204749
# 2022-02-01 00:00:00+00:00    0.028943
# 2022-03-01 00:00:00+00:00    0.024553
# 2022-04-01 00:00:00+00:00    0.007991
# 2022-05-01 00:00:00+00:00    0.006464
# 2022-06-01 00:00:00+00:00    0.009714
# 2022-07-01 00:00:00+00:00    0.069567
# 2022-08-01 00:00:00+00:00    0.014126
# 2022-09-01 00:00:00+00:00    0.005980
# 2022-10-01 00:00:00+00:00    0.056186
# 2022-11-01 00:00:00+00:00    0.005982
# 2022-12-01 00:00:00+00:00   -0.068115
# 2023-01-01 00:00:00+00:00   -0.018781
# 2023-02-01 00:00:00+00:00   -0.041527
# 2023-03-01 00:00:00+00:00    0.060723
# 2023-04-01 00:00:00+00:00    0.072238
# 2023-05-01 00:00:00+00:00    0.105312
# 2023-06-01 00:00:00+00:00    0.036975
# 2023-07-01 00:00:00+00:00    0.054420
# 2023-08-01 00:00:00+00:00   -0.083448
# 2023-09-01 00:00:00+00:00    0.045930
# 2023-10-01 00:00:00+00:00   -0.002517
# 2023-11-01 00:00:00+00:00    0.099965
# 2023-12-01 00:00:00+00:00    0.080818
# 2024-01-01 00:00:00+00:00    0.093335
# 2024-02-01 00:00:00+00:00    0.051963
# 2024-03-01 00:00:00+00:00   -0.016561
# 2024-04-01 00:00:00+00:00    0.016002
# 2024-05-01 00:00:00+00:00    0.020043
# 2024-06-01 00:00:00+00:00    0.034720
# 2024-07-01 00:00:00+00:00    0.129877
# 2024-08-01 00:00:00+00:00    0.094228
# 2024-09-01 00:00:00+00:00   -0.025751
# 2024-10-01 00:00:00+00:00   -0.058782
# Name: Return_TORNTPHARM, dtype: float64

# %%
TORNTPHARM_df1 = TORNTPHARM_df.dropna(axis=0)
TORNTPHARM_df1.head()
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                    TORNTPHARM.NS TORNTPHARM.NS TORNTPHARM.NS
# Date
# 2020-12-01 00:00:00+00:00   1334.355225   1401.349976   1428.275024
# 2021-01-01 00:00:00+00:00   1241.730591   1304.074951   1452.500000
# 2021-02-01 00:00:00+00:00   1156.057251   1214.099976   1401.449951
# 2021-03-01 00:00:00+00:00   1221.075195   1272.525024   1278.474976
# 2021-04-01 00:00:00+00:00   1203.899048   1254.625000   1341.000000
#
# Price                               Low          Open        Volume  \
# Ticker                    TORNTPHARM.NS TORNTPHARM.NS TORNTPHARM.NS
# Date
# 2020-12-01 00:00:00+00:00   1291.699951   1315.000000      18575692
# 2021-01-01 00:00:00+00:00   1285.650024   1401.449951      14160266
# 2021-02-01 00:00:00+00:00   1200.699951   1312.949951      21001760
# 2021-03-01 00:00:00+00:00   1155.550049   1203.400024      10866550
# 2021-04-01 00:00:00+00:00   1237.750000   1274.474976      11107348
#
# Price                     Return_TORNTPHARM
# Ticker
# Date
# 2020-12-01 00:00:00+00:00          0.069281
# 2021-01-01 00:00:00+00:00         -0.071942
# 2021-02-01 00:00:00+00:00         -0.071491
# 2021-03-01 00:00:00+00:00          0.054716
# 2021-04-01 00:00:00+00:00         -0.014166

# %%
TORNTPHARM_df['Return_TORNTPHARM'].plot(figsize=(8,5))
plt.show()

# %%
TORNTPHARM_df['Adj Close'].plot(figsize=(8,5))
plt.show()

# %%
TORNTPHARM_df1_returns = TORNTPHARM_df1['Return_TORNTPHARM']
TORNTPHARM_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.069281
# 2021-01-01 00:00:00+00:00   -0.071942
# 2021-02-01 00:00:00+00:00   -0.071491
# 2021-03-01 00:00:00+00:00    0.054716
# 2021-04-01 00:00:00+00:00   -0.014166
# Name: Return_TORNTPHARM, dtype: float64

# %%
nifty_df1_returns = nifty_df1['Return_NIFTY']
nifty_df1_returns.head()
# Out:
# Date
# 2020-12-01 00:00:00+00:00    0.078420
# 2021-01-01 00:00:00+00:00   -0.031172
# 2021-02-01 00:00:00+00:00    0.059024
# 2021-03-01 00:00:00+00:00    0.008299
# 2021-04-01 00:00:00+00:00   -0.014789
# Name: Return_NIFTY, dtype: float64

# %%
returns = pd.merge(nifty_df1_returns,TORNTPHARM_df1_returns,how='inner',on='Date')
returns.head()
returns.describe()
# Out:
#        Return_NIFTY  Return_TORNTPHARM
# count     47.000000          47.000000
# mean       0.012485           0.020102
# std        0.037319           0.062793
# min       -0.060019          -0.204749
# 25%       -0.018117          -0.010378
# 50%        0.010444           0.024553
# 75%        0.034510           0.061774
# max        0.090230           0.129877

# %%
sns.pairplot(returns)
plt.show()

# %%
sns.heatmap(returns.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
x = returns['Return_NIFTY']
y = returns['Return_TORNTPHARM']
x_sm = sm.add_constant(x)

# %% [markdown]
# #Assumptions of OLS regression
# ##A linear relationship between the dependent and independent variables - The linear regression model is linear in parameters
# ##The independent variables are not highly correlated with each other - no multicollinearity
# ##The variance of the residuals is constant - no heteroskedasticity
# ##Random sampling of observation and no autocorrelation
# ##Assumption of Normality of Errors

# %% [markdown]
# ##Ri = αi + βi(RM) + εi.........Market model
#
# • Ri = Return of security i
#
# • αi = The return from the asset that is not related to the market’s return. This is “alpha” return from the security
#
# • βi = Beta or the return from the security explained by the market index’s return
#
# • RM = The market index’s return
#
# • εi = Error term for past returns not explained by the regression equation

# %%
#Regression - Market model
model = sm.OLS(y,x_sm)

# %% [markdown]
# #OLS estimation or Ordinary Least square Minimizes the sum of squared errors

# %%
results = model.fit()

# %%
#Regression result
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Return_TORNTPHARM   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.139
# Method:                 Least Squares   F-statistic:                     8.427
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):            0.00571
# Time:                        08:38:11   Log-Likelihood:                 67.941
# No. Observations:                  47   AIC:                            -131.9
# Df Residuals:                      45   BIC:                            -128.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0118      0.009      1.311      0.197      -0.006       0.030
# Return_NIFTY     0.6682      0.230      2.903      0.006       0.205       1.132
# ==============================================================================
# Omnibus:                       16.900   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.329
# Skew:                          -1.163   Prob(JB):                     8.60e-06
# Kurtosis:                       5.549   Cond. No.                         27.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Beta for TORNTPHARM stock = 0.66 and is statistically significant as P value is 0.006 .

# %%
#Regression - Security Characteristic line
returns.info()
sns.regplot(x = 'Return_NIFTY', y = 'Return_TORNTPHARM', data = returns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 47 entries, 2020-12-01 00:00:00+00:00 to 2024-10-01 00:00:00+00:00
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Return_NIFTY       47 non-null     float64
#  1   Return_TORNTPHARM  47 non-null     float64
# dtypes: float64(2)
# memory usage: 1.1 KB
# <Axes: xlabel='Return_NIFTY', ylabel='Return_TORNTPHARM'>

# %%
print('resid', results.resid)
# Out:
# resid Date
# 2020-12-01 00:00:00+00:00    0.005117
# 2021-01-01 00:00:00+00:00   -0.062871
# 2021-02-01 00:00:00+00:00   -0.122693
# 2021-03-01 00:00:00+00:00    0.037411
# 2021-04-01 00:00:00+00:00   -0.016043
# 2021-05-01 00:00:00+00:00    0.034827
# 2021-06-01 00:00:00+00:00    0.038073
# 2021-07-01 00:00:00+00:00    0.048893
# 2021-08-01 00:00:00+00:00   -0.060788
# 2021-09-01 00:00:00+00:00   -0.036380
# 2021-10-01 00:00:00+00:00   -0.089550
# 2021-11-01 00:00:00+00:00    0.075563
# 2021-12-01 00:00:00+00:00    0.049300
# 2022-01-01 00:00:00+00:00   -0.213754
# 2022-02-01 00:00:00+00:00    0.037852
# 2022-03-01 00:00:00+00:00   -0.014230
# 2022-04-01 00:00:00+00:00    0.013658
# 2022-05-01 00:00:00+00:00    0.012439
# 2022-06-01 00:00:00+00:00    0.029315
# 2022-07-01 00:00:00+00:00    0.002773
# 2022-08-01 00:00:00+00:00   -0.020082
# 2022-09-01 00:00:00+00:00    0.018335
# 2022-10-01 00:00:00+00:00    0.006872
# 2022-11-01 00:00:00+00:00   -0.031174
# 2022-12-01 00:00:00+00:00   -0.055514
# 2023-01-01 00:00:00+00:00   -0.016210
# 2023-02-01 00:00:00+00:00   -0.046658
# 2023-03-01 00:00:00+00:00    0.048630
# 2023-04-01 00:00:00+00:00    0.036875
# 2023-05-01 00:00:00+00:00    0.077244
# 2023-06-01 00:00:00+00:00    0.003212
# 2023-07-01 00:00:00+00:00    0.024236
# 2023-08-01 00:00:00+00:00   -0.077948
# 2023-09-01 00:00:00+00:00    0.023972
# 2023-10-01 00:00:00+00:00    0.005854
# 2023-11-01 00:00:00+00:00    0.056401
# 2023-12-01 00:00:00+00:00    0.018621
# 2024-01-01 00:00:00+00:00    0.086106
# 2024-02-01 00:00:00+00:00    0.033271
# 2024-03-01 00:00:00+00:00   -0.038847
# 2024-04-01 00:00:00+00:00   -0.003259
# 2024-05-01 00:00:00+00:00    0.012979
# 2024-06-01 00:00:00+00:00   -0.021358
# 2024-07-01 00:00:00+00:00    0.095599
# 2024-08-01 00:00:00+00:00    0.077383
# 2024-09-01 00:00:00+00:00   -0.053020
# 2024-10-01 00:00:00+00:00   -0.030434
# dtype: float64

# %%
#Histogram of residuals
sns.distplot(results.resid)
results.resid.describe()
# Out:
# <ipython-input-238-a89ebdceef41>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(results.resid)
# count    4.700000e+01
# mean    -5.905442e-19
# std      5.762828e-02
# min     -2.137543e-01
# 25%     -3.080384e-02
# 50%      6.872094e-03
# 75%      3.714310e-02
# max      9.559939e-02
# dtype: float64

# %%
#Checking for Homoskedasticity of errors (Assumption requirement of linear regression)
#perform White's test
from statsmodels.stats.diagnostic import het_white
white_test = het_white(results.resid,  results.model.exog)

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 0.8502277187551124, 'Test Statistic p-value': 0.6536953515466086, 'F-Statistic': 0.4053109882887579, 'F-Test p-value': 0.6692332318711174}

# %% [markdown]
# #The errors are homoskedastic as per the White test

# %%
#Testing for Normality of errors (Assumption requirement of linear regression)
sm.qqplot(results.resid,line='45',fit=True,dist=stats.norm)

# %%
stats.normaltest(results.resid)
# Out:
# NormaltestResult(statistic=16.899719802462727, pvalue=0.00021393038465174612)

# %% [markdown]
# We can see that since we are plotting the data with the theoretical quantiles of a normal distribution, we are getting almost a straight line, though some points are not exactly on the line.
# The D’Agostino’s K-squared test result suggests that the null hypothesis that the distribution is normal cannot be rejected at 1% significance level.

# %%
stats.normaltest(results.resid)
# Out:
# NormaltestResult(statistic=16.899719802462727, pvalue=0.00021393038465174612)

# %% [markdown]
# We can see that since we are plotting the data with the theoretical quantiles of a normal distribution, we are getting almost a straight line, though some points are not exactly on the line.
# The D’Agostino’s K-squared test result suggests that the null hypothesis that the distribution is normal cannot be rejected at 1% significance level.
